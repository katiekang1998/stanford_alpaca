# %%
import re
import numpy as np
import tqdm

# %%
def evaluate_expression(expression):
    # Step 1: Add spaces around operators for clarity
    expression = re.sub(r'([+\-*/])', r' \1 ', expression)
    
    # Step 2: Split the expression into parts
    parts = expression.split()
    
    # Step 3: Initialize the steps list
    steps = []
    steps.append(expression)
    
    # Step 4: Handle multiplication and division first
    while '*' in parts or '/' in parts:
        for i in range(len(parts)):
            if parts[i] == '*':
                result = int(parts[i-1]) * int(parts[i+1])
                parts[i-1:i+2] = [str(result)]
                step_expression = ' '.join(parts)
                steps.append(step_expression)
                break
            elif parts[i] == '/':
                result = int(parts[i-1]) / int(parts[i+1])
                parts[i-1:i+2] = [str(result)]
                step_expression = ' '.join(parts)
                steps.append(step_expression)
                break
    
    # Step 5: Handle addition and subtraction
    while '+' in parts or '-' in parts:
        for i in range(len(parts)):
            if parts[i] == '+':
                result = int(parts[i-1]) + int(parts[i+1])
                parts[i-1:i+2] = [str(result)]
                step_expression = ' '.join(parts)
                steps.append(step_expression)
                break
            elif parts[i] == '-':
                result = int(parts[i-1]) - int(parts[i+1])
                parts[i-1:i+2] = [str(result)]
                step_expression = ' '.join(parts)
                steps.append(step_expression)
                break
    
    return steps

# %%
def generate_input(num_steps):
    input_str = str(np.random.randint(0, high=20))
    
    for i in range(num_steps):
        operator = np.random.choice(['+', '-', '*'])
        operand = str(np.random.randint(0, high=20))
        input_str += operator + operand
    return input_str

# %%
input_str = generate_input(2)

# %%
input_str
# Out:
# '45-45*32'

# %%
len(np.load('../arithmetic/3step_eval.npy'))
# Out:
# 1000

# %%
dataset = []

# for i in tqdm.tqdm(range(50000)):
for i in tqdm.tqdm(range(1000)):
    input_str = generate_input(7)
    steps = evaluate_expression(input_str)
    dataset.append(evaluate_expression(input_str))
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 6214.20it/s]

# %%
dataset
# Out:
# [['19 * 7 + 19 - 6', '133 + 19 - 6', '152 - 6', '146'],
#  ['6 * 9 + 6 + 5', '54 + 6 + 5', '60 + 5', '65'],
#  ['15 + 19 * 8 + 15', '15 + 152 + 15', '167 + 15', '182'],
#  ['2 - 2 + 7 * 16', '2 - 2 + 112', '0 + 112', '112'],
#  ['12 + 12 * 13 * 5', '12 + 156 * 5', '12 + 780', '792'],
#  ['5 + 6 - 5 * 16', '5 + 6 - 80', '11 - 80', '-69'],
#  ['13 - 6 * 6 - 17', '13 - 36 - 17', '-23 - 17', '-40'],
#  ['7 * 16 - 8 * 12', '112 - 8 * 12', '112 - 96', '16'],
#  ['8 * 5 + 8 - 0', '40 + 8 - 0', '48 - 0', '48'],
#  ['18 * 3 + 12 * 4', '54 + 12 * 4', '54 + 48', '102'],
#  ['3 + 13 - 6 - 8', '16 - 6 - 8', '10 - 8', '2'],
#  ['3 * 1 * 12 * 11', '3 * 12 * 11', '36 * 11', '396'],
#  ['14 + 4 - 8 - 13', '18 - 8 - 13', '10 - 13', '-3'],
#  ['10 - 13 * 15 - 7', '10 - 195 - 7', '-185 - 7', '-192'],
#  ['16 - 2 - 9 + 4', '14 - 9 + 4', '5 + 4', '9'],
#  ['1 * 11 - 17 - 0', '11 - 17 - 0', '-6 - 0', '-6'],
#  ['15 * 6 - 14 + 4', '90 - 14 + 4', '76 + 4', '80'],
#  ['10 - 4 - 14 + 15', '6 - 14 + 15', '-8 + 15', '7'],
#  ['11 - 13 + 14 + 14', '-2 + 14 + 14', '12 + 14', '26'],
#  ['18 + 2 - 15 + 6', '20 - 15 + 6', '5 + 6', '11'],
#  ['13 - 18 * 19 - 15', '13 - 342 - 15', '-329 - 15', '-344'],
#  ['2 * 5 + 8 - 15', '10 + 8 - 15', '18 - 15', '3'],
#  ['1 - 13 + 2 * 4', '1 - 13 + 8', '-12 + 8', '-4'],
#  ['16 * 3 - 19 - 11', '48 - 19 - 11', '29 - 11', '18'],
#  ['14 * 3 - 10 - 13', '42 - 10 - 13', '32 - 13', '19'],
#  ['18 - 12 - 8 * 16', '18 - 12 - 128', '6 - 128', '-122'],
#  ['2 + 8 + 3 + 9', '10 + 3 + 9', '13 + 9', '22'],
#  ['18 + 3 + 6 * 10', '18 + 3 + 60', '21 + 60', '81'],
#  ['18 - 18 * 19 + 19', '18 - 342 + 19', '-324 + 19', '-305'],
#  ['2 - 10 + 15 - 4', '-8 + 15 - 4', '7 - 4', '3'],
#  ['11 - 14 + 14 + 11', '-3 + 14 + 11', '11 + 11', '22'],
#  ['14 - 17 * 3 - 9', '14 - 51 - 9', '-37 - 9', '-46'],
#  ['5 - 6 * 0 - 2', '5 - 0 - 2', '5 - 2', '3'],
#  ['7 + 3 * 11 - 18', '7 + 33 - 18', '40 - 18', '22'],
#  ['14 * 18 + 16 + 2', '252 + 16 + 2', '268 + 2', '270'],
#  ['19 + 17 - 0 - 19', '36 - 0 - 19', '36 - 19', '17'],
#  ['11 + 16 + 10 - 18', '27 + 10 - 18', '37 - 18', '19'],
#  ['17 - 13 * 15 - 19', '17 - 195 - 19', '-178 - 19', '-197'],
#  ['2 + 3 + 2 * 13', '2 + 3 + 26', '5 + 26', '31'],
#  ['3 - 17 - 7 - 9', '-14 - 7 - 9', '-21 - 9', '-30'],
#  ['6 * 4 + 0 * 18', '24 + 0 * 18', '24 + 0', '24'],
#  ['5 * 4 - 10 - 5', '20 - 10 - 5', '10 - 5', '5'],
#  ['3 - 11 - 6 + 18', '-8 - 6 + 18', '-14 + 18', '4'],
#  ['2 * 15 - 3 * 5', '30 - 3 * 5', '30 - 15', '15'],
#  ['0 + 14 * 6 - 14', '0 + 84 - 14', '84 - 14', '70'],
#  ['3 + 9 * 15 + 18', '3 + 135 + 18', '138 + 18', '156'],
#  ['8 + 12 - 18 - 14', '20 - 18 - 14', '2 - 14', '-12'],
#  ['5 - 18 - 8 + 6', '-13 - 8 + 6', '-21 + 6', '-15'],
#  ['1 - 10 - 17 - 17', '-9 - 17 - 17', '-26 - 17', '-43'],
#  ['18 + 15 - 4 - 5', '33 - 4 - 5', '29 - 5', '24'],
#  ['13 + 16 + 3 - 10', '29 + 3 - 10', '32 - 10', '22'],
#  ['8 - 11 * 15 * 1', '8 - 165 * 1', '8 - 165', '-157'],
#  ['16 - 5 - 11 + 3', '11 - 11 + 3', '0 + 3', '3'],
#  ['9 + 10 + 5 + 0', '19 + 5 + 0', '24 + 0', '24'],
#  ['14 * 12 - 2 + 3', '168 - 2 + 3', '166 + 3', '169'],
#  ['14 + 6 - 3 + 9', '20 - 3 + 9', '17 + 9', '26'],
#  ['15 - 6 * 1 - 13', '15 - 6 - 13', '9 - 13', '-4'],
#  ['2 + 6 * 15 - 3', '2 + 90 - 3', '92 - 3', '89'],
#  ['16 - 8 * 7 * 7', '16 - 56 * 7', '16 - 392', '-376'],
#  ['5 * 14 - 9 + 10', '70 - 9 + 10', '61 + 10', '71'],
#  ['10 - 0 * 10 * 18', '10 - 0 * 18', '10 - 0', '10'],
#  ['1 - 7 - 18 * 3', '1 - 7 - 54', '-6 - 54', '-60'],
#  ['17 * 3 - 19 + 8', '51 - 19 + 8', '32 + 8', '40'],
#  ['4 - 6 - 17 - 18', '-2 - 17 - 18', '-19 - 18', '-37'],
#  ['5 - 9 - 18 + 14', '-4 - 18 + 14', '-22 + 14', '-8'],
#  ['14 - 3 * 12 * 15', '14 - 36 * 15', '14 - 540', '-526'],
#  ['18 - 15 + 14 - 11', '3 + 14 - 11', '17 - 11', '6'],
#  ['7 - 19 * 14 + 2', '7 - 266 + 2', '-259 + 2', '-257'],
#  ['4 - 1 * 0 + 9', '4 - 0 + 9', '4 + 9', '13'],
#  ['13 - 9 * 6 - 12', '13 - 54 - 12', '-41 - 12', '-53'],
#  ['11 * 17 + 10 * 2', '187 + 10 * 2', '187 + 20', '207'],
#  ['4 - 17 * 12 * 3', '4 - 204 * 3', '4 - 612', '-608'],
#  ['18 - 2 * 13 + 2', '18 - 26 + 2', '-8 + 2', '-6'],
#  ['16 * 0 * 4 * 15', '0 * 4 * 15', '0 * 15', '0'],
#  ['19 - 18 + 16 + 15', '1 + 16 + 15', '17 + 15', '32'],
#  ['15 * 10 * 19 + 3', '150 * 19 + 3', '2850 + 3', '2853'],
#  ['0 * 18 * 17 * 11', '0 * 17 * 11', '0 * 11', '0'],
#  ['2 + 3 + 3 + 0', '5 + 3 + 0', '8 + 0', '8'],
#  ['10 + 5 * 17 * 3', '10 + 85 * 3', '10 + 255', '265'],
#  ['14 - 3 + 7 - 8', '11 + 7 - 8', '18 - 8', '10'],
#  ['5 * 2 + 5 + 5', '10 + 5 + 5', '15 + 5', '20'],
#  ['8 + 1 * 4 * 5', '8 + 4 * 5', '8 + 20', '28'],
#  ['11 + 14 + 1 * 8', '11 + 14 + 8', '25 + 8', '33'],
#  ['16 + 1 - 10 + 15', '17 - 10 + 15', '7 + 15', '22'],
#  ['18 + 17 - 19 * 11', '18 + 17 - 209', '35 - 209', '-174'],
#  ['1 + 14 + 16 * 15', '1 + 14 + 240', '15 + 240', '255'],
#  ['15 - 5 + 6 - 5', '10 + 6 - 5', '16 - 5', '11'],
#  ['1 * 5 - 1 * 16', '5 - 1 * 16', '5 - 16', '-11'],
#  ['10 - 0 + 18 - 11', '10 + 18 - 11', '28 - 11', '17'],
#  ['16 - 13 - 2 + 6', '3 - 2 + 6', '1 + 6', '7'],
#  ['3 - 4 * 7 - 10', '3 - 28 - 10', '-25 - 10', '-35'],
#  ['5 + 5 - 12 - 16', '10 - 12 - 16', '-2 - 16', '-18'],
#  ['10 - 6 * 13 - 17', '10 - 78 - 17', '-68 - 17', '-85'],
#  ['0 * 12 - 5 + 13', '0 - 5 + 13', '-5 + 13', '8'],
#  ['13 * 17 * 9 - 13', '221 * 9 - 13', '1989 - 13', '1976'],
#  ['18 + 6 + 11 - 16', '24 + 11 - 16', '35 - 16', '19'],
#  ['6 + 13 - 11 * 11', '6 + 13 - 121', '19 - 121', '-102'],
#  ['0 * 3 + 6 + 1', '0 + 6 + 1', '6 + 1', '7'],
#  ['1 + 12 * 8 - 11', '1 + 96 - 11', '97 - 11', '86'],
#  ['2 + 12 + 10 * 5', '2 + 12 + 50', '14 + 50', '64'],
#  ['1 * 17 - 11 + 1', '17 - 11 + 1', '6 + 1', '7'],
#  ['11 + 15 - 19 * 8', '11 + 15 - 152', '26 - 152', '-126'],
#  ['14 + 15 - 16 - 1', '29 - 16 - 1', '13 - 1', '12'],
#  ['11 * 5 * 9 - 3', '55 * 9 - 3', '495 - 3', '492'],
#  ['5 + 4 * 19 * 18', '5 + 76 * 18', '5 + 1368', '1373'],
#  ['18 * 18 + 15 + 10', '324 + 15 + 10', '339 + 10', '349'],
#  ['9 + 8 * 10 * 4', '9 + 80 * 4', '9 + 320', '329'],
#  ['5 + 8 + 17 * 13', '5 + 8 + 221', '13 + 221', '234'],
#  ['17 + 10 + 7 - 12', '27 + 7 - 12', '34 - 12', '22'],
#  ['7 - 10 - 3 + 5', '-3 - 3 + 5', '-6 + 5', '-1'],
#  ['0 + 2 + 18 - 17', '2 + 18 - 17', '20 - 17', '3'],
#  ['9 * 6 - 16 - 0', '54 - 16 - 0', '38 - 0', '38'],
#  ['3 - 11 * 3 - 13', '3 - 33 - 13', '-30 - 13', '-43'],
#  ['14 + 3 + 17 * 1', '14 + 3 + 17', '17 + 17', '34'],
#  ['8 * 19 - 5 * 2', '152 - 5 * 2', '152 - 10', '142'],
#  ['1 * 12 - 8 * 19', '12 - 8 * 19', '12 - 152', '-140'],
#  ['5 + 17 * 19 * 4', '5 + 323 * 4', '5 + 1292', '1297'],
#  ['6 - 11 + 17 * 6', '6 - 11 + 102', '-5 + 102', '97'],
#  ['10 - 12 + 18 * 3', '10 - 12 + 54', '-2 + 54', '52'],
#  ['9 + 8 * 12 + 11', '9 + 96 + 11', '105 + 11', '116'],
#  ['14 - 0 * 9 + 2', '14 - 0 + 2', '14 + 2', '16'],
#  ['18 - 1 * 9 * 5', '18 - 9 * 5', '18 - 45', '-27'],
#  ['9 - 19 + 3 * 19', '9 - 19 + 57', '-10 + 57', '47'],
#  ['1 + 12 + 19 + 1', '13 + 19 + 1', '32 + 1', '33'],
#  ['14 + 12 * 16 + 1', '14 + 192 + 1', '206 + 1', '207'],
#  ['5 + 2 * 5 - 8', '5 + 10 - 8', '15 - 8', '7'],
#  ['0 - 11 * 10 - 7', '0 - 110 - 7', '-110 - 7', '-117'],
#  ['10 - 16 + 12 * 14', '10 - 16 + 168', '-6 + 168', '162'],
#  ['0 - 8 * 4 - 2', '0 - 32 - 2', '-32 - 2', '-34'],
#  ['13 + 0 + 3 * 7', '13 + 0 + 21', '13 + 21', '34'],
#  ['13 + 19 - 7 + 6', '32 - 7 + 6', '25 + 6', '31'],
#  ['6 * 9 * 17 + 19', '54 * 17 + 19', '918 + 19', '937'],
#  ['5 - 18 - 8 * 16', '5 - 18 - 128', '-13 - 128', '-141'],
#  ['19 * 14 - 17 + 2', '266 - 17 + 2', '249 + 2', '251'],
#  ['6 + 14 - 5 * 15', '6 + 14 - 75', '20 - 75', '-55'],
#  ['12 * 18 * 14 - 4', '216 * 14 - 4', '3024 - 4', '3020'],
#  ['19 + 2 * 2 * 0', '19 + 4 * 0', '19 + 0', '19'],
#  ['14 * 5 - 10 - 13', '70 - 10 - 13', '60 - 13', '47'],
#  ['7 * 15 + 0 * 1', '105 + 0 * 1', '105 + 0', '105'],
#  ['0 + 19 - 13 - 10', '19 - 13 - 10', '6 - 10', '-4'],
#  ['2 * 17 * 14 + 17', '34 * 14 + 17', '476 + 17', '493'],
#  ['19 * 13 - 17 * 2', '247 - 17 * 2', '247 - 34', '213'],
#  ['12 - 6 * 12 * 11', '12 - 72 * 11', '12 - 792', '-780'],
#  ['8 * 12 + 1 + 11', '96 + 1 + 11', '97 + 11', '108'],
#  ['19 - 13 - 10 - 17', '6 - 10 - 17', '-4 - 17', '-21'],
#  ['6 * 11 - 19 - 7', '66 - 19 - 7', '47 - 7', '40'],
#  ['4 + 15 - 5 + 1', '19 - 5 + 1', '14 + 1', '15'],
#  ['0 * 8 * 5 + 11', '0 * 5 + 11', '0 + 11', '11'],
#  ['2 + 1 - 16 * 15', '2 + 1 - 240', '3 - 240', '-237'],
#  ['13 - 19 + 13 + 0', '-6 + 13 + 0', '7 + 0', '7'],
#  ['5 - 7 * 9 + 13', '5 - 63 + 13', '-58 + 13', '-45'],
#  ['16 * 16 - 10 + 13', '256 - 10 + 13', '246 + 13', '259'],
#  ['6 * 17 * 14 * 2', '102 * 14 * 2', '1428 * 2', '2856'],
#  ['17 * 2 - 13 + 8', '34 - 13 + 8', '21 + 8', '29'],
#  ['10 - 7 * 4 + 16', '10 - 28 + 16', '-18 + 16', '-2'],
#  ['5 - 13 + 1 * 0', '5 - 13 + 0', '-8 + 0', '-8'],
#  ['16 * 10 + 15 + 4', '160 + 15 + 4', '175 + 4', '179'],
#  ['18 * 1 - 14 * 14', '18 - 14 * 14', '18 - 196', '-178'],
#  ['16 * 18 + 1 + 10', '288 + 1 + 10', '289 + 10', '299'],
#  ['7 * 9 * 7 + 0', '63 * 7 + 0', '441 + 0', '441'],
#  ['3 - 4 * 2 + 3', '3 - 8 + 3', '-5 + 3', '-2'],
#  ['19 * 4 * 7 * 16', '76 * 7 * 16', '532 * 16', '8512'],
#  ['5 - 14 + 9 + 2', '-9 + 9 + 2', '0 + 2', '2'],
#  ['14 + 16 * 8 * 0', '14 + 128 * 0', '14 + 0', '14'],
#  ['17 + 8 * 4 + 15', '17 + 32 + 15', '49 + 15', '64'],
#  ['5 * 10 - 14 - 0', '50 - 14 - 0', '36 - 0', '36'],
#  ['9 + 12 - 19 * 13', '9 + 12 - 247', '21 - 247', '-226'],
#  ['4 - 5 * 3 - 16', '4 - 15 - 16', '-11 - 16', '-27'],
#  ['8 + 0 * 15 * 9', '8 + 0 * 9', '8 + 0', '8'],
#  ['9 * 17 * 16 * 16', '153 * 16 * 16', '2448 * 16', '39168'],
#  ['10 + 5 * 9 * 1', '10 + 45 * 1', '10 + 45', '55'],
#  ['17 + 19 - 7 + 5', '36 - 7 + 5', '29 + 5', '34'],
#  ['14 + 11 - 11 + 9', '25 - 11 + 9', '14 + 9', '23'],
#  ['4 - 4 * 18 + 8', '4 - 72 + 8', '-68 + 8', '-60'],
#  ['17 * 9 + 16 + 2', '153 + 16 + 2', '169 + 2', '171'],
#  ['11 + 10 + 12 + 17', '21 + 12 + 17', '33 + 17', '50'],
#  ['14 - 0 * 3 + 15', '14 - 0 + 15', '14 + 15', '29'],
#  ['6 * 6 * 9 * 0', '36 * 9 * 0', '324 * 0', '0'],
#  ['16 - 7 - 12 * 12', '16 - 7 - 144', '9 - 144', '-135'],
#  ['16 * 4 + 17 * 18', '64 + 17 * 18', '64 + 306', '370'],
#  ['2 - 5 - 11 + 0', '-3 - 11 + 0', '-14 + 0', '-14'],
#  ['9 * 12 + 5 * 14', '108 + 5 * 14', '108 + 70', '178'],
#  ['19 + 10 * 11 - 14', '19 + 110 - 14', '129 - 14', '115'],
#  ['2 - 15 - 9 * 10', '2 - 15 - 90', '-13 - 90', '-103'],
#  ['13 + 0 * 19 + 13', '13 + 0 + 13', '13 + 13', '26'],
#  ['15 - 19 * 14 + 11', '15 - 266 + 11', '-251 + 11', '-240'],
#  ['14 + 19 + 3 + 9', '33 + 3 + 9', '36 + 9', '45'],
#  ['9 * 1 + 2 * 9', '9 + 2 * 9', '9 + 18', '27'],
#  ['3 * 11 * 4 * 11', '33 * 4 * 11', '132 * 11', '1452'],
#  ['6 * 8 * 3 - 19', '48 * 3 - 19', '144 - 19', '125'],
#  ['13 - 2 + 3 * 16', '13 - 2 + 48', '11 + 48', '59'],
#  ['4 + 6 * 8 - 17', '4 + 48 - 17', '52 - 17', '35'],
#  ['18 + 8 + 18 + 4', '26 + 18 + 4', '44 + 4', '48'],
#  ['10 + 5 - 2 - 15', '15 - 2 - 15', '13 - 15', '-2'],
#  ['7 * 4 * 6 * 2', '28 * 6 * 2', '168 * 2', '336'],
#  ['6 - 3 * 2 - 16', '6 - 6 - 16', '0 - 16', '-16'],
#  ['18 + 6 + 6 * 19', '18 + 6 + 114', '24 + 114', '138'],
#  ['1 - 5 + 6 - 0', '-4 + 6 - 0', '2 - 0', '2'],
#  ['19 + 4 * 10 + 12', '19 + 40 + 12', '59 + 12', '71'],
#  ['12 + 5 - 5 + 7', '17 - 5 + 7', '12 + 7', '19'],
#  ['4 - 5 * 17 * 14', '4 - 85 * 14', '4 - 1190', '-1186'],
#  ['12 + 3 * 9 - 14', '12 + 27 - 14', '39 - 14', '25'],
#  ['15 - 12 - 2 + 17', '3 - 2 + 17', '1 + 17', '18'],
#  ['15 + 19 + 10 * 16', '15 + 19 + 160', '34 + 160', '194'],
#  ['8 + 9 + 11 - 4', '17 + 11 - 4', '28 - 4', '24'],
#  ['5 - 3 - 18 * 13', '5 - 3 - 234', '2 - 234', '-232'],
#  ['7 - 0 - 3 + 15', '7 - 3 + 15', '4 + 15', '19'],
#  ['7 - 10 - 2 * 9', '7 - 10 - 18', '-3 - 18', '-21'],
#  ['7 + 9 - 18 + 6', '16 - 18 + 6', '-2 + 6', '4'],
#  ['19 - 8 - 19 * 5', '19 - 8 - 95', '11 - 95', '-84'],
#  ['6 * 1 + 15 - 13', '6 + 15 - 13', '21 - 13', '8'],
#  ['10 + 5 - 4 + 19', '15 - 4 + 19', '11 + 19', '30'],
#  ['15 - 17 * 11 - 18', '15 - 187 - 18', '-172 - 18', '-190'],
#  ['5 + 15 * 2 + 5', '5 + 30 + 5', '35 + 5', '40'],
#  ['15 - 15 * 7 * 10', '15 - 105 * 10', '15 - 1050', '-1035'],
#  ['14 * 16 * 5 * 9', '224 * 5 * 9', '1120 * 9', '10080'],
#  ['13 * 17 + 19 * 6', '221 + 19 * 6', '221 + 114', '335'],
#  ['11 + 10 * 7 - 10', '11 + 70 - 10', '81 - 10', '71'],
#  ['4 + 13 * 16 * 5', '4 + 208 * 5', '4 + 1040', '1044'],
#  ['13 * 9 + 1 * 13', '117 + 1 * 13', '117 + 13', '130'],
#  ['6 - 12 + 8 + 9', '-6 + 8 + 9', '2 + 9', '11'],
#  ['10 + 17 * 9 + 1', '10 + 153 + 1', '163 + 1', '164'],
#  ['5 - 0 - 18 + 1', '5 - 18 + 1', '-13 + 1', '-12'],
#  ['15 - 9 * 19 * 13', '15 - 171 * 13', '15 - 2223', '-2208'],
#  ['12 * 6 * 3 - 8', '72 * 3 - 8', '216 - 8', '208'],
#  ['17 - 0 - 0 + 2', '17 - 0 + 2', '17 + 2', '19'],
#  ['15 + 15 - 9 + 13', '30 - 9 + 13', '21 + 13', '34'],
#  ['1 - 8 - 15 + 2', '-7 - 15 + 2', '-22 + 2', '-20'],
#  ['5 - 13 + 0 * 16', '5 - 13 + 0', '-8 + 0', '-8'],
#  ['14 * 4 + 14 - 2', '56 + 14 - 2', '70 - 2', '68'],
#  ['7 - 12 - 3 - 7', '-5 - 3 - 7', '-8 - 7', '-15'],
#  ['8 * 18 + 10 * 0', '144 + 10 * 0', '144 + 0', '144'],
#  ['18 - 8 + 11 - 5', '10 + 11 - 5', '21 - 5', '16'],
#  ['4 * 1 + 4 - 10', '4 + 4 - 10', '8 - 10', '-2'],
#  ['4 - 13 - 5 - 16', '-9 - 5 - 16', '-14 - 16', '-30'],
#  ['9 * 15 + 14 + 0', '135 + 14 + 0', '149 + 0', '149'],
#  ['1 + 1 - 15 + 2', '2 - 15 + 2', '-13 + 2', '-11'],
#  ['5 * 8 - 18 - 11', '40 - 18 - 11', '22 - 11', '11'],
#  ['8 + 10 - 11 * 5', '8 + 10 - 55', '18 - 55', '-37'],
#  ['10 * 6 + 5 - 3', '60 + 5 - 3', '65 - 3', '62'],
#  ['15 - 13 + 17 * 9', '15 - 13 + 153', '2 + 153', '155'],
#  ['3 * 16 + 15 - 2', '48 + 15 - 2', '63 - 2', '61'],
#  ['16 + 17 - 6 * 2', '16 + 17 - 12', '33 - 12', '21'],
#  ['16 + 11 + 17 * 5', '16 + 11 + 85', '27 + 85', '112'],
#  ['18 - 17 - 10 - 16', '1 - 10 - 16', '-9 - 16', '-25'],
#  ['16 * 18 * 18 - 2', '288 * 18 - 2', '5184 - 2', '5182'],
#  ['7 + 14 - 5 * 17', '7 + 14 - 85', '21 - 85', '-64'],
#  ['17 + 6 + 8 * 7', '17 + 6 + 56', '23 + 56', '79'],
#  ['3 + 8 - 1 - 15', '11 - 1 - 15', '10 - 15', '-5'],
#  ['7 * 9 - 9 * 2', '63 - 9 * 2', '63 - 18', '45'],
#  ['18 + 1 * 5 * 17', '18 + 5 * 17', '18 + 85', '103'],
#  ['18 * 5 * 7 + 5', '90 * 7 + 5', '630 + 5', '635'],
#  ['7 + 3 * 15 - 2', '7 + 45 - 2', '52 - 2', '50'],
#  ['16 + 13 * 17 - 10', '16 + 221 - 10', '237 - 10', '227'],
#  ['7 + 6 * 13 * 10', '7 + 78 * 10', '7 + 780', '787'],
#  ['7 + 19 * 9 - 13', '7 + 171 - 13', '178 - 13', '165'],
#  ['7 * 7 * 3 + 7', '49 * 3 + 7', '147 + 7', '154'],
#  ['9 * 9 - 4 * 19', '81 - 4 * 19', '81 - 76', '5'],
#  ['8 * 11 - 17 * 1', '88 - 17 * 1', '88 - 17', '71'],
#  ['16 - 7 + 13 + 17', '9 + 13 + 17', '22 + 17', '39'],
#  ['9 * 8 * 5 * 17', '72 * 5 * 17', '360 * 17', '6120'],
#  ['7 * 6 - 11 * 4', '42 - 11 * 4', '42 - 44', '-2'],
#  ['18 - 14 + 15 + 16', '4 + 15 + 16', '19 + 16', '35'],
#  ['2 + 11 - 9 - 12', '13 - 9 - 12', '4 - 12', '-8'],
#  ['16 * 18 * 4 + 5', '288 * 4 + 5', '1152 + 5', '1157'],
#  ['3 - 18 - 3 * 7', '3 - 18 - 21', '-15 - 21', '-36'],
#  ['18 - 4 + 18 + 15', '14 + 18 + 15', '32 + 15', '47'],
#  ['19 + 2 * 14 * 14', '19 + 28 * 14', '19 + 392', '411'],
#  ['3 * 11 - 16 * 9', '33 - 16 * 9', '33 - 144', '-111'],
#  ['11 + 2 * 2 * 15', '11 + 4 * 15', '11 + 60', '71'],
#  ['12 * 5 + 4 - 15', '60 + 4 - 15', '64 - 15', '49'],
#  ['12 * 19 - 4 + 18', '228 - 4 + 18', '224 + 18', '242'],
#  ['10 * 2 + 8 + 14', '20 + 8 + 14', '28 + 14', '42'],
#  ['19 * 11 - 8 - 14', '209 - 8 - 14', '201 - 14', '187'],
#  ['19 + 7 + 9 + 7', '26 + 9 + 7', '35 + 7', '42'],
#  ['19 + 18 + 8 + 10', '37 + 8 + 10', '45 + 10', '55'],
#  ['16 * 2 + 2 + 0', '32 + 2 + 0', '34 + 0', '34'],
#  ['17 - 8 + 1 + 18', '9 + 1 + 18', '10 + 18', '28'],
#  ['7 - 19 * 12 * 13', '7 - 228 * 13', '7 - 2964', '-2957'],
#  ['3 + 14 + 6 + 15', '17 + 6 + 15', '23 + 15', '38'],
#  ['15 * 16 - 10 - 14', '240 - 10 - 14', '230 - 14', '216'],
#  ['12 - 11 - 17 - 17', '1 - 17 - 17', '-16 - 17', '-33'],
#  ['5 - 5 * 1 - 14', '5 - 5 - 14', '0 - 14', '-14'],
#  ['16 + 7 * 18 + 15', '16 + 126 + 15', '142 + 15', '157'],
#  ['3 - 18 * 11 * 1', '3 - 198 * 1', '3 - 198', '-195'],
#  ['19 - 6 * 6 * 11', '19 - 36 * 11', '19 - 396', '-377'],
#  ['6 * 11 - 4 * 17', '66 - 4 * 17', '66 - 68', '-2'],
#  ['18 * 4 - 14 + 6', '72 - 14 + 6', '58 + 6', '64'],
#  ['11 * 6 * 3 - 2', '66 * 3 - 2', '198 - 2', '196'],
#  ['5 * 8 + 13 + 11', '40 + 13 + 11', '53 + 11', '64'],
#  ['17 - 18 - 14 - 9', '-1 - 14 - 9', '-15 - 9', '-24'],
#  ['2 - 3 + 9 * 17', '2 - 3 + 153', '-1 + 153', '152'],
#  ['11 + 14 - 1 + 12', '25 - 1 + 12', '24 + 12', '36'],
#  ['17 - 2 - 11 - 7', '15 - 11 - 7', '4 - 7', '-3'],
#  ['3 - 9 + 1 + 5', '-6 + 1 + 5', '-5 + 5', '0'],
#  ['13 * 9 - 9 + 18', '117 - 9 + 18', '108 + 18', '126'],
#  ['4 * 10 * 18 - 18', '40 * 18 - 18', '720 - 18', '702'],
#  ['6 - 12 + 11 + 3', '-6 + 11 + 3', '5 + 3', '8'],
#  ['1 - 0 * 15 * 8', '1 - 0 * 8', '1 - 0', '1'],
#  ['14 - 5 * 13 + 1', '14 - 65 + 1', '-51 + 1', '-50'],
#  ['15 * 9 + 14 + 10', '135 + 14 + 10', '149 + 10', '159'],
#  ['17 * 18 + 13 - 17', '306 + 13 - 17', '319 - 17', '302'],
#  ['5 + 14 + 19 - 14', '19 + 19 - 14', '38 - 14', '24'],
#  ['17 * 1 * 8 + 11', '17 * 8 + 11', '136 + 11', '147'],
#  ['19 + 11 + 12 * 13', '19 + 11 + 156', '30 + 156', '186'],
#  ['10 * 5 * 3 + 8', '50 * 3 + 8', '150 + 8', '158'],
#  ['12 + 7 + 0 - 16', '19 + 0 - 16', '19 - 16', '3'],
#  ['19 * 11 * 7 - 10', '209 * 7 - 10', '1463 - 10', '1453'],
#  ['15 + 8 - 9 + 13', '23 - 9 + 13', '14 + 13', '27'],
#  ['6 - 19 - 14 + 11', '-13 - 14 + 11', '-27 + 11', '-16'],
#  ['1 * 3 + 10 + 19', '3 + 10 + 19', '13 + 19', '32'],
#  ['17 + 9 - 0 * 19', '17 + 9 - 0', '26 - 0', '26'],
#  ['9 - 13 + 19 * 16', '9 - 13 + 304', '-4 + 304', '300'],
#  ['11 * 11 * 12 * 3', '121 * 12 * 3', '1452 * 3', '4356'],
#  ['6 + 18 + 11 + 4', '24 + 11 + 4', '35 + 4', '39'],
#  ['5 + 4 - 1 + 13', '9 - 1 + 13', '8 + 13', '21'],
#  ['4 + 16 + 5 * 19', '4 + 16 + 95', '20 + 95', '115'],
#  ['12 + 1 - 6 + 16', '13 - 6 + 16', '7 + 16', '23'],
#  ['5 - 0 * 7 * 16', '5 - 0 * 16', '5 - 0', '5'],
#  ['15 + 13 - 2 * 3', '15 + 13 - 6', '28 - 6', '22'],
#  ['0 + 11 + 6 * 6', '0 + 11 + 36', '11 + 36', '47'],
#  ['0 - 11 - 4 - 11', '-11 - 4 - 11', '-15 - 11', '-26'],
#  ['14 - 2 + 14 * 16', '14 - 2 + 224', '12 + 224', '236'],
#  ['16 * 9 - 18 + 15', '144 - 18 + 15', '126 + 15', '141'],
#  ['2 + 4 + 19 + 4', '6 + 19 + 4', '25 + 4', '29'],
#  ['11 * 17 + 7 + 7', '187 + 7 + 7', '194 + 7', '201'],
#  ['5 + 18 + 14 - 16', '23 + 14 - 16', '37 - 16', '21'],
#  ['19 - 18 * 8 + 4', '19 - 144 + 4', '-125 + 4', '-121'],
#  ['18 - 4 + 3 - 8', '14 + 3 - 8', '17 - 8', '9'],
#  ['13 + 3 * 1 * 17', '13 + 3 * 17', '13 + 51', '64'],
#  ['13 - 12 - 18 - 11', '1 - 18 - 11', '-17 - 11', '-28'],
#  ['16 * 3 - 17 - 7', '48 - 17 - 7', '31 - 7', '24'],
#  ['12 + 19 + 10 + 17', '31 + 10 + 17', '41 + 17', '58'],
#  ['17 - 13 * 1 * 8', '17 - 13 * 8', '17 - 104', '-87'],
#  ['14 + 4 - 12 - 10', '18 - 12 - 10', '6 - 10', '-4'],
#  ['17 + 16 * 6 + 7', '17 + 96 + 7', '113 + 7', '120'],
#  ['8 - 14 + 3 * 13', '8 - 14 + 39', '-6 + 39', '33'],
#  ['19 + 4 + 2 * 6', '19 + 4 + 12', '23 + 12', '35'],
#  ['3 * 2 * 4 - 3', '6 * 4 - 3', '24 - 3', '21'],
#  ['11 - 13 * 16 + 10', '11 - 208 + 10', '-197 + 10', '-187'],
#  ['19 * 9 - 16 - 4', '171 - 16 - 4', '155 - 4', '151'],
#  ['6 * 10 + 9 - 2', '60 + 9 - 2', '69 - 2', '67'],
#  ['12 * 14 * 6 + 14', '168 * 6 + 14', '1008 + 14', '1022'],
#  ['10 * 3 - 2 + 4', '30 - 2 + 4', '28 + 4', '32'],
#  ['5 + 7 * 4 + 1', '5 + 28 + 1', '33 + 1', '34'],
#  ['14 + 0 + 7 * 9', '14 + 0 + 63', '14 + 63', '77'],
#  ['14 * 18 + 14 * 0', '252 + 14 * 0', '252 + 0', '252'],
#  ['17 + 1 + 5 * 12', '17 + 1 + 60', '18 + 60', '78'],
#  ['14 * 1 - 18 - 12', '14 - 18 - 12', '-4 - 12', '-16'],
#  ['5 + 3 - 6 * 9', '5 + 3 - 54', '8 - 54', '-46'],
#  ['7 - 7 - 0 - 7', '0 - 0 - 7', '0 - 7', '-7'],
#  ['8 + 16 + 10 * 6', '8 + 16 + 60', '24 + 60', '84'],
#  ['7 - 2 - 3 * 4', '7 - 2 - 12', '5 - 12', '-7'],
#  ['10 * 5 * 14 - 9', '50 * 14 - 9', '700 - 9', '691'],
#  ['2 * 19 + 10 + 14', '38 + 10 + 14', '48 + 14', '62'],
#  ['15 * 19 + 11 * 19', '285 + 11 * 19', '285 + 209', '494'],
#  ['14 * 17 + 3 - 11', '238 + 3 - 11', '241 - 11', '230'],
#  ['10 - 12 * 6 + 2', '10 - 72 + 2', '-62 + 2', '-60'],
#  ['15 - 10 - 9 - 19', '5 - 9 - 19', '-4 - 19', '-23'],
#  ['5 + 8 - 12 + 2', '13 - 12 + 2', '1 + 2', '3'],
#  ['14 + 13 * 17 + 6', '14 + 221 + 6', '235 + 6', '241'],
#  ['6 + 4 * 1 + 5', '6 + 4 + 5', '10 + 5', '15'],
#  ['18 + 9 + 11 * 11', '18 + 9 + 121', '27 + 121', '148'],
#  ['7 + 12 - 7 * 12', '7 + 12 - 84', '19 - 84', '-65'],
#  ['2 * 16 + 13 - 12', '32 + 13 - 12', '45 - 12', '33'],
#  ['11 * 14 * 16 - 10', '154 * 16 - 10', '2464 - 10', '2454'],
#  ['13 + 7 + 19 + 2', '20 + 19 + 2', '39 + 2', '41'],
#  ['0 - 9 - 12 + 3', '-9 - 12 + 3', '-21 + 3', '-18'],
#  ['13 - 17 + 2 + 17', '-4 + 2 + 17', '-2 + 17', '15'],
#  ['18 + 5 + 1 * 7', '18 + 5 + 7', '23 + 7', '30'],
#  ['1 * 9 * 5 - 18', '9 * 5 - 18', '45 - 18', '27'],
#  ['12 * 16 * 15 - 13', '192 * 15 - 13', '2880 - 13', '2867'],
#  ['14 * 19 - 15 * 18', '266 - 15 * 18', '266 - 270', '-4'],
#  ['6 * 19 * 2 - 0', '114 * 2 - 0', '228 - 0', '228'],
#  ['9 * 9 - 10 + 6', '81 - 10 + 6', '71 + 6', '77'],
#  ['19 - 13 - 14 - 8', '6 - 14 - 8', '-8 - 8', '-16'],
#  ['2 + 1 * 15 - 17', '2 + 15 - 17', '17 - 17', '0'],
#  ['3 - 11 + 4 + 7', '-8 + 4 + 7', '-4 + 7', '3'],
#  ['12 - 15 * 7 * 18', '12 - 105 * 18', '12 - 1890', '-1878'],
#  ['10 * 9 + 10 * 5', '90 + 10 * 5', '90 + 50', '140'],
#  ['3 + 8 + 10 - 15', '11 + 10 - 15', '21 - 15', '6'],
#  ['12 * 2 - 2 * 2', '24 - 2 * 2', '24 - 4', '20'],
#  ['4 * 1 + 11 + 15', '4 + 11 + 15', '15 + 15', '30'],
#  ['0 * 13 + 5 + 3', '0 + 5 + 3', '5 + 3', '8'],
#  ['7 + 10 + 5 * 18', '7 + 10 + 90', '17 + 90', '107'],
#  ['7 - 3 + 6 - 12', '4 + 6 - 12', '10 - 12', '-2'],
#  ['2 * 12 * 8 * 8', '24 * 8 * 8', '192 * 8', '1536'],
#  ['13 + 14 + 14 - 10', '27 + 14 - 10', '41 - 10', '31'],
#  ['7 + 6 + 11 + 13', '13 + 11 + 13', '24 + 13', '37'],
#  ['7 - 14 - 11 - 16', '-7 - 11 - 16', '-18 - 16', '-34'],
#  ['19 * 12 + 16 + 17', '228 + 16 + 17', '244 + 17', '261'],
#  ['14 * 2 * 9 - 11', '28 * 9 - 11', '252 - 11', '241'],
#  ['4 * 14 - 0 - 9', '56 - 0 - 9', '56 - 9', '47'],
#  ['13 - 10 * 1 + 17', '13 - 10 + 17', '3 + 17', '20'],
#  ['5 * 13 * 19 * 1', '65 * 19 * 1', '1235 * 1', '1235'],
#  ['2 * 10 + 9 + 11', '20 + 9 + 11', '29 + 11', '40'],
#  ['18 - 4 + 14 - 19', '14 + 14 - 19', '28 - 19', '9'],
#  ['6 * 12 - 4 + 14', '72 - 4 + 14', '68 + 14', '82'],
#  ['12 + 1 + 2 + 4', '13 + 2 + 4', '15 + 4', '19'],
#  ['10 * 4 - 2 * 8', '40 - 2 * 8', '40 - 16', '24'],
#  ['15 - 9 + 2 - 2', '6 + 2 - 2', '8 - 2', '6'],
#  ['4 * 16 * 1 - 9', '64 * 1 - 9', '64 - 9', '55'],
#  ['11 + 7 + 19 - 16', '18 + 19 - 16', '37 - 16', '21'],
#  ['3 - 10 - 8 * 6', '3 - 10 - 48', '-7 - 48', '-55'],
#  ['16 * 15 + 11 * 19', '240 + 11 * 19', '240 + 209', '449'],
#  ['11 * 14 * 0 - 8', '154 * 0 - 8', '0 - 8', '-8'],
#  ['14 * 8 + 14 + 17', '112 + 14 + 17', '126 + 17', '143'],
#  ['3 * 17 * 19 + 4', '51 * 19 + 4', '969 + 4', '973'],
#  ['19 - 4 - 17 - 4', '15 - 17 - 4', '-2 - 4', '-6'],
#  ['7 * 0 - 15 - 15', '0 - 15 - 15', '-15 - 15', '-30'],
#  ['2 * 18 + 2 * 15', '36 + 2 * 15', '36 + 30', '66'],
#  ['1 + 7 * 11 * 9', '1 + 77 * 9', '1 + 693', '694'],
#  ['7 + 10 - 15 - 12', '17 - 15 - 12', '2 - 12', '-10'],
#  ['16 * 17 * 0 - 13', '272 * 0 - 13', '0 - 13', '-13'],
#  ['16 + 11 - 2 * 1', '16 + 11 - 2', '27 - 2', '25'],
#  ['8 - 0 + 10 + 9', '8 + 10 + 9', '18 + 9', '27'],
#  ['19 * 9 + 11 - 9', '171 + 11 - 9', '182 - 9', '173'],
#  ['18 + 7 * 19 + 3', '18 + 133 + 3', '151 + 3', '154'],
#  ['7 + 0 * 0 * 14', '7 + 0 * 14', '7 + 0', '7'],
#  ['13 * 14 * 14 - 13', '182 * 14 - 13', '2548 - 13', '2535'],
#  ['13 * 2 - 14 - 6', '26 - 14 - 6', '12 - 6', '6'],
#  ['1 + 3 - 11 - 5', '4 - 11 - 5', '-7 - 5', '-12'],
#  ['15 * 4 - 19 - 18', '60 - 19 - 18', '41 - 18', '23'],
#  ['14 - 6 - 10 + 7', '8 - 10 + 7', '-2 + 7', '5'],
#  ['2 * 15 - 11 * 18', '30 - 11 * 18', '30 - 198', '-168'],
#  ['13 + 13 * 19 * 11', '13 + 247 * 11', '13 + 2717', '2730'],
#  ['9 + 1 - 17 * 4', '9 + 1 - 68', '10 - 68', '-58'],
#  ['11 + 2 + 15 - 2', '13 + 15 - 2', '28 - 2', '26'],
#  ['11 * 15 * 2 * 13', '165 * 2 * 13', '330 * 13', '4290'],
#  ['0 - 2 - 16 * 7', '0 - 2 - 112', '-2 - 112', '-114'],
#  ['5 - 2 - 0 * 1', '5 - 2 - 0', '3 - 0', '3'],
#  ['18 + 15 - 13 * 16', '18 + 15 - 208', '33 - 208', '-175'],
#  ['0 + 13 - 4 * 5', '0 + 13 - 20', '13 - 20', '-7'],
#  ['0 * 6 + 16 * 18', '0 + 16 * 18', '0 + 288', '288'],
#  ['19 - 4 - 15 * 7', '19 - 4 - 105', '15 - 105', '-90'],
#  ['11 * 7 + 11 * 9', '77 + 11 * 9', '77 + 99', '176'],
#  ['3 - 13 + 2 * 1', '3 - 13 + 2', '-10 + 2', '-8'],
#  ['19 + 18 + 4 + 14', '37 + 4 + 14', '41 + 14', '55'],
#  ['3 + 3 - 4 - 14', '6 - 4 - 14', '2 - 14', '-12'],
#  ['15 + 8 * 13 + 4', '15 + 104 + 4', '119 + 4', '123'],
#  ['11 - 14 + 11 * 9', '11 - 14 + 99', '-3 + 99', '96'],
#  ['16 * 12 * 15 - 1', '192 * 15 - 1', '2880 - 1', '2879'],
#  ['1 * 11 * 7 + 5', '11 * 7 + 5', '77 + 5', '82'],
#  ['3 + 7 * 10 - 8', '3 + 70 - 8', '73 - 8', '65'],
#  ['2 * 9 * 18 * 16', '18 * 18 * 16', '324 * 16', '5184'],
#  ['12 - 17 * 12 + 19', '12 - 204 + 19', '-192 + 19', '-173'],
#  ['8 * 19 + 19 * 7', '152 + 19 * 7', '152 + 133', '285'],
#  ['14 + 1 + 15 * 4', '14 + 1 + 60', '15 + 60', '75'],
#  ['18 - 6 + 7 + 4', '12 + 7 + 4', '19 + 4', '23'],
#  ['13 + 13 * 6 + 14', '13 + 78 + 14', '91 + 14', '105'],
#  ['2 - 17 - 9 * 4', '2 - 17 - 36', '-15 - 36', '-51'],
#  ['2 * 15 - 8 - 9', '30 - 8 - 9', '22 - 9', '13'],
#  ['3 - 0 * 11 + 0', '3 - 0 + 0', '3 + 0', '3'],
#  ['17 + 16 - 9 - 13', '33 - 9 - 13', '24 - 13', '11'],
#  ['9 + 16 + 17 - 7', '25 + 17 - 7', '42 - 7', '35'],
#  ['7 - 10 - 16 - 3', '-3 - 16 - 3', '-19 - 3', '-22'],
#  ['13 * 1 - 0 + 2', '13 - 0 + 2', '13 + 2', '15'],
#  ['18 - 3 * 11 - 1', '18 - 33 - 1', '-15 - 1', '-16'],
#  ['12 + 11 - 9 + 0', '23 - 9 + 0', '14 + 0', '14'],
#  ['18 + 10 + 18 * 6', '18 + 10 + 108', '28 + 108', '136'],
#  ['4 * 1 * 16 - 6', '4 * 16 - 6', '64 - 6', '58'],
#  ['1 - 18 * 17 + 12', '1 - 306 + 12', '-305 + 12', '-293'],
#  ['13 * 16 + 12 * 8', '208 + 12 * 8', '208 + 96', '304'],
#  ['17 - 19 - 10 * 14', '17 - 19 - 140', '-2 - 140', '-142'],
#  ['8 * 7 - 0 + 9', '56 - 0 + 9', '56 + 9', '65'],
#  ['2 * 14 * 13 * 12', '28 * 13 * 12', '364 * 12', '4368'],
#  ['8 * 11 * 7 * 9', '88 * 7 * 9', '616 * 9', '5544'],
#  ['9 - 1 - 0 + 5', '8 - 0 + 5', '8 + 5', '13'],
#  ['4 * 14 + 15 * 14', '56 + 15 * 14', '56 + 210', '266'],
#  ['12 + 14 + 19 * 10', '12 + 14 + 190', '26 + 190', '216'],
#  ['11 - 17 + 14 * 6', '11 - 17 + 84', '-6 + 84', '78'],
#  ['5 * 11 * 16 + 1', '55 * 16 + 1', '880 + 1', '881'],
#  ['12 + 13 - 14 - 14', '25 - 14 - 14', '11 - 14', '-3'],
#  ['2 + 4 - 10 + 3', '6 - 10 + 3', '-4 + 3', '-1'],
#  ['16 * 12 * 9 - 1', '192 * 9 - 1', '1728 - 1', '1727'],
#  ['13 - 17 + 0 + 4', '-4 + 0 + 4', '-4 + 4', '0'],
#  ['10 * 8 - 4 * 8', '80 - 4 * 8', '80 - 32', '48'],
#  ['9 * 16 - 15 + 1', '144 - 15 + 1', '129 + 1', '130'],
#  ['0 - 19 * 10 - 15', '0 - 190 - 15', '-190 - 15', '-205'],
#  ['18 - 11 * 6 - 2', '18 - 66 - 2', '-48 - 2', '-50'],
#  ['5 - 6 * 2 - 19', '5 - 12 - 19', '-7 - 19', '-26'],
#  ['10 - 3 + 8 + 19', '7 + 8 + 19', '15 + 19', '34'],
#  ['10 + 16 + 4 * 12', '10 + 16 + 48', '26 + 48', '74'],
#  ['0 + 6 - 15 - 15', '6 - 15 - 15', '-9 - 15', '-24'],
#  ['2 * 3 - 6 + 14', '6 - 6 + 14', '0 + 14', '14'],
#  ['12 + 4 + 0 * 4', '12 + 4 + 0', '16 + 0', '16'],
#  ['19 - 19 - 1 - 6', '0 - 1 - 6', '-1 - 6', '-7'],
#  ['16 - 8 - 3 - 12', '8 - 3 - 12', '5 - 12', '-7'],
#  ['18 - 8 - 14 * 9', '18 - 8 - 126', '10 - 126', '-116'],
#  ['11 * 6 * 9 + 19', '66 * 9 + 19', '594 + 19', '613'],
#  ['5 - 4 * 8 - 4', '5 - 32 - 4', '-27 - 4', '-31'],
#  ['4 * 17 * 7 - 0', '68 * 7 - 0', '476 - 0', '476'],
#  ['10 * 14 + 12 - 11', '140 + 12 - 11', '152 - 11', '141'],
#  ['4 * 5 * 7 * 6', '20 * 7 * 6', '140 * 6', '840'],
#  ['11 - 5 - 16 - 2', '6 - 16 - 2', '-10 - 2', '-12'],
#  ['11 + 9 - 7 + 9', '20 - 7 + 9', '13 + 9', '22'],
#  ['13 * 19 * 11 + 13', '247 * 11 + 13', '2717 + 13', '2730'],
#  ['8 + 18 - 5 - 19', '26 - 5 - 19', '21 - 19', '2'],
#  ['5 * 3 + 14 - 1', '15 + 14 - 1', '29 - 1', '28'],
#  ['3 - 14 + 9 * 12', '3 - 14 + 108', '-11 + 108', '97'],
#  ['14 * 9 * 3 * 1', '126 * 3 * 1', '378 * 1', '378'],
#  ['3 + 5 - 2 - 10', '8 - 2 - 10', '6 - 10', '-4'],
#  ['3 - 8 + 13 + 3', '-5 + 13 + 3', '8 + 3', '11'],
#  ['14 - 7 + 16 * 18', '14 - 7 + 288', '7 + 288', '295'],
#  ['18 + 6 * 16 * 15', '18 + 96 * 15', '18 + 1440', '1458'],
#  ['7 + 19 + 11 * 4', '7 + 19 + 44', '26 + 44', '70'],
#  ['12 + 6 + 16 * 1', '12 + 6 + 16', '18 + 16', '34'],
#  ['4 - 8 - 7 * 5', '4 - 8 - 35', '-4 - 35', '-39'],
#  ['6 + 3 - 19 - 14', '9 - 19 - 14', '-10 - 14', '-24'],
#  ['4 * 18 - 11 * 8', '72 - 11 * 8', '72 - 88', '-16'],
#  ['18 - 14 + 10 - 13', '4 + 10 - 13', '14 - 13', '1'],
#  ['3 + 8 * 15 + 15', '3 + 120 + 15', '123 + 15', '138'],
#  ['15 * 3 - 10 - 4', '45 - 10 - 4', '35 - 4', '31'],
#  ['1 - 5 - 14 + 2', '-4 - 14 + 2', '-18 + 2', '-16'],
#  ['4 - 16 * 5 - 13', '4 - 80 - 13', '-76 - 13', '-89'],
#  ['7 * 1 - 9 * 12', '7 - 9 * 12', '7 - 108', '-101'],
#  ['4 * 6 * 2 * 3', '24 * 2 * 3', '48 * 3', '144'],
#  ['6 - 2 * 12 * 5', '6 - 24 * 5', '6 - 120', '-114'],
#  ['15 * 13 - 6 - 4', '195 - 6 - 4', '189 - 4', '185'],
#  ['11 - 0 - 9 * 5', '11 - 0 - 45', '11 - 45', '-34'],
#  ['16 * 17 - 1 - 8', '272 - 1 - 8', '271 - 8', '263'],
#  ['11 - 8 - 14 - 7', '3 - 14 - 7', '-11 - 7', '-18'],
#  ['14 + 7 + 10 + 19', '21 + 10 + 19', '31 + 19', '50'],
#  ['14 * 6 * 0 + 16', '84 * 0 + 16', '0 + 16', '16'],
#  ['6 * 18 * 13 * 6', '108 * 13 * 6', '1404 * 6', '8424'],
#  ['11 * 8 + 7 * 10', '88 + 7 * 10', '88 + 70', '158'],
#  ['18 - 12 + 5 - 16', '6 + 5 - 16', '11 - 16', '-5'],
#  ['12 + 4 + 7 * 7', '12 + 4 + 49', '16 + 49', '65'],
#  ['3 + 9 * 15 * 1', '3 + 135 * 1', '3 + 135', '138'],
#  ['18 - 1 - 16 - 7', '17 - 16 - 7', '1 - 7', '-6'],
#  ['13 - 17 + 6 + 6', '-4 + 6 + 6', '2 + 6', '8'],
#  ['4 * 3 + 18 - 7', '12 + 18 - 7', '30 - 7', '23'],
#  ['19 - 18 + 5 + 17', '1 + 5 + 17', '6 + 17', '23'],
#  ['15 + 16 + 3 + 14', '31 + 3 + 14', '34 + 14', '48'],
#  ['9 + 13 + 5 + 6', '22 + 5 + 6', '27 + 6', '33'],
#  ['3 - 7 * 12 * 8', '3 - 84 * 8', '3 - 672', '-669'],
#  ['5 + 11 - 13 + 2', '16 - 13 + 2', '3 + 2', '5'],
#  ['0 - 13 - 5 - 5', '-13 - 5 - 5', '-18 - 5', '-23'],
#  ['2 * 8 * 16 - 3', '16 * 16 - 3', '256 - 3', '253'],
#  ['12 - 12 + 5 + 3', '0 + 5 + 3', '5 + 3', '8'],
#  ['8 * 2 - 16 * 11', '16 - 16 * 11', '16 - 176', '-160'],
#  ['2 * 5 + 13 + 4', '10 + 13 + 4', '23 + 4', '27'],
#  ['8 - 17 * 9 + 5', '8 - 153 + 5', '-145 + 5', '-140'],
#  ['3 + 18 * 18 + 7', '3 + 324 + 7', '327 + 7', '334'],
#  ['7 * 17 + 3 + 19', '119 + 3 + 19', '122 + 19', '141'],
#  ['13 + 8 * 3 - 5', '13 + 24 - 5', '37 - 5', '32'],
#  ['2 - 3 - 0 * 18', '2 - 3 - 0', '-1 - 0', '-1'],
#  ['6 + 16 * 3 - 12', '6 + 48 - 12', '54 - 12', '42'],
#  ['19 + 3 - 13 - 4', '22 - 13 - 4', '9 - 4', '5'],
#  ['5 + 14 - 7 + 2', '19 - 7 + 2', '12 + 2', '14'],
#  ['4 * 14 - 2 * 3', '56 - 2 * 3', '56 - 6', '50'],
#  ['0 + 9 * 3 * 8', '0 + 27 * 8', '0 + 216', '216'],
#  ['19 + 4 * 18 - 9', '19 + 72 - 9', '91 - 9', '82'],
#  ['9 * 12 - 1 * 4', '108 - 1 * 4', '108 - 4', '104'],
#  ['7 - 8 + 9 - 17', '-1 + 9 - 17', '8 - 17', '-9'],
#  ['3 + 9 * 10 + 0', '3 + 90 + 0', '93 + 0', '93'],
#  ['8 * 18 - 14 + 8', '144 - 14 + 8', '130 + 8', '138'],
#  ['15 + 19 * 16 - 1', '15 + 304 - 1', '319 - 1', '318'],
#  ['4 - 7 + 18 - 1', '-3 + 18 - 1', '15 - 1', '14'],
#  ['1 - 3 * 14 - 13', '1 - 42 - 13', '-41 - 13', '-54'],
#  ['19 + 17 - 9 - 5', '36 - 9 - 5', '27 - 5', '22'],
#  ['18 + 9 - 5 * 8', '18 + 9 - 40', '27 - 40', '-13'],
#  ['17 * 4 + 4 - 9', '68 + 4 - 9', '72 - 9', '63'],
#  ['10 - 0 * 9 + 8', '10 - 0 + 8', '10 + 8', '18'],
#  ['14 * 13 - 1 - 13', '182 - 1 - 13', '181 - 13', '168'],
#  ['2 - 2 * 17 + 17', '2 - 34 + 17', '-32 + 17', '-15'],
#  ['8 - 12 * 14 - 6', '8 - 168 - 6', '-160 - 6', '-166'],
#  ['4 * 8 - 12 + 12', '32 - 12 + 12', '20 + 12', '32'],
#  ['14 * 19 + 14 - 10', '266 + 14 - 10', '280 - 10', '270'],
#  ['10 + 2 + 16 + 12', '12 + 16 + 12', '28 + 12', '40'],
#  ['18 - 0 - 15 - 19', '18 - 15 - 19', '3 - 19', '-16'],
#  ['19 * 14 * 17 - 15', '266 * 17 - 15', '4522 - 15', '4507'],
#  ['4 - 12 * 14 - 7', '4 - 168 - 7', '-164 - 7', '-171'],
#  ['5 * 14 + 10 * 0', '70 + 10 * 0', '70 + 0', '70'],
#  ['4 * 17 - 10 * 8', '68 - 10 * 8', '68 - 80', '-12'],
#  ['0 + 18 * 9 + 8', '0 + 162 + 8', '162 + 8', '170'],
#  ['19 * 14 - 12 + 3', '266 - 12 + 3', '254 + 3', '257'],
#  ['19 + 13 + 4 + 7', '32 + 4 + 7', '36 + 7', '43'],
#  ['5 + 19 - 8 - 3', '24 - 8 - 3', '16 - 3', '13'],
#  ['19 + 0 + 17 - 13', '19 + 17 - 13', '36 - 13', '23'],
#  ['3 * 4 - 19 + 15', '12 - 19 + 15', '-7 + 15', '8'],
#  ['11 + 19 - 7 - 6', '30 - 7 - 6', '23 - 6', '17'],
#  ['11 + 1 + 16 * 10', '11 + 1 + 160', '12 + 160', '172'],
#  ['7 * 17 * 3 + 11', '119 * 3 + 11', '357 + 11', '368'],
#  ['7 * 2 - 8 * 3', '14 - 8 * 3', '14 - 24', '-10'],
#  ['12 * 19 + 15 - 12', '228 + 15 - 12', '243 - 12', '231'],
#  ['11 * 19 - 3 - 4', '209 - 3 - 4', '206 - 4', '202'],
#  ['6 + 5 * 4 * 14', '6 + 20 * 14', '6 + 280', '286'],
#  ['16 - 18 - 1 + 13', '-2 - 1 + 13', '-3 + 13', '10'],
#  ['2 - 12 + 17 * 7', '2 - 12 + 119', '-10 + 119', '109'],
#  ['12 + 7 - 6 * 15', '12 + 7 - 90', '19 - 90', '-71'],
#  ['16 + 5 * 18 + 7', '16 + 90 + 7', '106 + 7', '113'],
#  ['10 - 9 - 13 + 12', '1 - 13 + 12', '-12 + 12', '0'],
#  ['3 * 0 * 8 - 0', '0 * 8 - 0', '0 - 0', '0'],
#  ['5 * 10 * 7 - 0', '50 * 7 - 0', '350 - 0', '350'],
#  ['12 * 16 + 5 + 10', '192 + 5 + 10', '197 + 10', '207'],
#  ['12 - 10 + 10 + 4', '2 + 10 + 4', '12 + 4', '16'],
#  ['15 + 3 * 7 + 4', '15 + 21 + 4', '36 + 4', '40'],
#  ['6 + 19 + 14 - 13', '25 + 14 - 13', '39 - 13', '26'],
#  ['16 - 7 * 13 * 13', '16 - 91 * 13', '16 - 1183', '-1167'],
#  ['3 + 10 * 1 - 16', '3 + 10 - 16', '13 - 16', '-3'],
#  ['17 - 5 - 4 * 8', '17 - 5 - 32', '12 - 32', '-20'],
#  ['0 * 13 - 17 - 5', '0 - 17 - 5', '-17 - 5', '-22'],
#  ['9 * 19 * 4 - 1', '171 * 4 - 1', '684 - 1', '683'],
#  ['16 + 5 - 17 - 1', '21 - 17 - 1', '4 - 1', '3'],
#  ['11 + 0 + 6 - 9', '11 + 6 - 9', '17 - 9', '8'],
#  ['14 * 14 - 15 * 3', '196 - 15 * 3', '196 - 45', '151'],
#  ['15 - 13 - 4 - 1', '2 - 4 - 1', '-2 - 1', '-3'],
#  ['5 * 6 - 14 - 1', '30 - 14 - 1', '16 - 1', '15'],
#  ['2 * 18 + 7 + 9', '36 + 7 + 9', '43 + 9', '52'],
#  ['18 - 14 * 1 - 17', '18 - 14 - 17', '4 - 17', '-13'],
#  ['5 * 12 - 6 - 8', '60 - 6 - 8', '54 - 8', '46'],
#  ['18 - 2 + 12 * 2', '18 - 2 + 24', '16 + 24', '40'],
#  ['19 - 16 + 0 + 18', '3 + 0 + 18', '3 + 18', '21'],
#  ['2 * 0 - 1 - 18', '0 - 1 - 18', '-1 - 18', '-19'],
#  ['16 + 8 - 12 * 0', '16 + 8 - 0', '24 - 0', '24'],
#  ['19 + 8 * 17 - 16', '19 + 136 - 16', '155 - 16', '139'],
#  ['13 - 1 + 11 + 17', '12 + 11 + 17', '23 + 17', '40'],
#  ['14 * 17 * 8 + 15', '238 * 8 + 15', '1904 + 15', '1919'],
#  ['1 * 3 + 6 * 4', '3 + 6 * 4', '3 + 24', '27'],
#  ['6 + 8 * 10 + 2', '6 + 80 + 2', '86 + 2', '88'],
#  ['14 + 1 * 4 + 15', '14 + 4 + 15', '18 + 15', '33'],
#  ['11 * 15 - 17 + 19', '165 - 17 + 19', '148 + 19', '167'],
#  ['13 * 19 - 7 - 3', '247 - 7 - 3', '240 - 3', '237'],
#  ['13 - 10 + 12 * 2', '13 - 10 + 24', '3 + 24', '27'],
#  ['6 + 16 - 10 + 15', '22 - 10 + 15', '12 + 15', '27'],
#  ['18 + 18 - 16 * 2', '18 + 18 - 32', '36 - 32', '4'],
#  ['2 + 7 * 9 + 6', '2 + 63 + 6', '65 + 6', '71'],
#  ['10 * 15 + 7 * 7', '150 + 7 * 7', '150 + 49', '199'],
#  ['10 + 18 + 14 + 15', '28 + 14 + 15', '42 + 15', '57'],
#  ['15 - 2 + 17 * 14', '15 - 2 + 238', '13 + 238', '251'],
#  ['16 - 10 + 16 + 3', '6 + 16 + 3', '22 + 3', '25'],
#  ['16 * 1 + 10 + 18', '16 + 10 + 18', '26 + 18', '44'],
#  ['10 - 12 + 17 - 12', '-2 + 17 - 12', '15 - 12', '3'],
#  ['11 + 0 - 11 - 5', '11 - 11 - 5', '0 - 5', '-5'],
#  ['4 + 16 * 12 - 17', '4 + 192 - 17', '196 - 17', '179'],
#  ['4 + 5 + 13 * 14', '4 + 5 + 182', '9 + 182', '191'],
#  ['19 * 11 + 16 - 19', '209 + 16 - 19', '225 - 19', '206'],
#  ['7 - 14 + 0 * 12', '7 - 14 + 0', '-7 + 0', '-7'],
#  ['17 - 15 + 7 + 7', '2 + 7 + 7', '9 + 7', '16'],
#  ['6 * 4 - 16 - 8', '24 - 16 - 8', '8 - 8', '0'],
#  ['13 + 7 - 13 + 16', '20 - 13 + 16', '7 + 16', '23'],
#  ['3 * 9 * 9 - 9', '27 * 9 - 9', '243 - 9', '234'],
#  ['11 + 14 * 8 + 3', '11 + 112 + 3', '123 + 3', '126'],
#  ['1 * 2 - 19 + 6', '2 - 19 + 6', '-17 + 6', '-11'],
#  ['14 - 9 - 11 - 8', '5 - 11 - 8', '-6 - 8', '-14'],
#  ['5 + 6 * 12 + 1', '5 + 72 + 1', '77 + 1', '78'],
#  ['7 + 15 * 13 + 0', '7 + 195 + 0', '202 + 0', '202'],
#  ['14 * 19 * 15 * 19', '266 * 15 * 19', '3990 * 19', '75810'],
#  ['17 - 14 * 8 + 18', '17 - 112 + 18', '-95 + 18', '-77'],
#  ['3 - 8 + 12 + 5', '-5 + 12 + 5', '7 + 5', '12'],
#  ['11 * 11 - 6 * 13', '121 - 6 * 13', '121 - 78', '43'],
#  ['3 - 4 + 4 + 12', '-1 + 4 + 12', '3 + 12', '15'],
#  ['15 - 15 + 0 - 13', '0 + 0 - 13', '0 - 13', '-13'],
#  ['1 + 14 * 7 + 7', '1 + 98 + 7', '99 + 7', '106'],
#  ['12 - 14 - 19 - 17', '-2 - 19 - 17', '-21 - 17', '-38'],
#  ['6 + 16 + 3 - 3', '22 + 3 - 3', '25 - 3', '22'],
#  ['5 + 6 + 2 + 14', '11 + 2 + 14', '13 + 14', '27'],
#  ['18 * 12 + 13 - 10', '216 + 13 - 10', '229 - 10', '219'],
#  ['1 * 17 + 13 + 3', '17 + 13 + 3', '30 + 3', '33'],
#  ['7 * 3 + 11 * 7', '21 + 11 * 7', '21 + 77', '98'],
#  ['15 + 7 - 0 - 13', '22 - 0 - 13', '22 - 13', '9'],
#  ['19 + 19 - 13 * 11', '19 + 19 - 143', '38 - 143', '-105'],
#  ['19 * 2 + 12 * 1', '38 + 12 * 1', '38 + 12', '50'],
#  ['8 * 19 - 5 - 18', '152 - 5 - 18', '147 - 18', '129'],
#  ['11 + 19 + 0 * 0', '11 + 19 + 0', '30 + 0', '30'],
#  ['2 * 3 + 4 + 13', '6 + 4 + 13', '10 + 13', '23'],
#  ['9 * 4 - 8 + 0', '36 - 8 + 0', '28 + 0', '28'],
#  ['12 * 9 * 5 + 10', '108 * 5 + 10', '540 + 10', '550'],
#  ['15 - 4 * 10 + 18', '15 - 40 + 18', '-25 + 18', '-7'],
#  ['19 * 19 + 16 * 18', '361 + 16 * 18', '361 + 288', '649'],
#  ['13 - 13 + 10 * 15', '13 - 13 + 150', '0 + 150', '150'],
#  ['18 - 13 - 2 + 4', '5 - 2 + 4', '3 + 4', '7'],
#  ['15 * 1 + 5 + 10', '15 + 5 + 10', '20 + 10', '30'],
#  ['12 - 17 + 15 - 13', '-5 + 15 - 13', '10 - 13', '-3'],
#  ['3 + 19 * 9 - 16', '3 + 171 - 16', '174 - 16', '158'],
#  ['17 - 6 * 15 + 12', '17 - 90 + 12', '-73 + 12', '-61'],
#  ['15 * 4 * 16 + 11', '60 * 16 + 11', '960 + 11', '971'],
#  ['1 * 6 - 13 - 12', '6 - 13 - 12', '-7 - 12', '-19'],
#  ['10 * 7 - 16 * 8', '70 - 16 * 8', '70 - 128', '-58'],
#  ['15 * 9 * 12 - 4', '135 * 12 - 4', '1620 - 4', '1616'],
#  ['12 + 14 - 8 * 11', '12 + 14 - 88', '26 - 88', '-62'],
#  ['8 - 11 - 3 + 18', '-3 - 3 + 18', '-6 + 18', '12'],
#  ['12 * 9 - 9 + 19', '108 - 9 + 19', '99 + 19', '118'],
#  ['15 - 18 * 7 + 1', '15 - 126 + 1', '-111 + 1', '-110'],
#  ['9 + 11 * 17 * 2', '9 + 187 * 2', '9 + 374', '383'],
#  ['5 * 1 - 10 + 19', '5 - 10 + 19', '-5 + 19', '14'],
#  ['10 * 10 - 19 + 13', '100 - 19 + 13', '81 + 13', '94'],
#  ['12 + 3 * 17 - 19', '12 + 51 - 19', '63 - 19', '44'],
#  ['15 - 12 + 16 + 11', '3 + 16 + 11', '19 + 11', '30'],
#  ['2 * 5 * 0 + 9', '10 * 0 + 9', '0 + 9', '9'],
#  ['12 + 1 * 11 * 17', '12 + 11 * 17', '12 + 187', '199'],
#  ['13 - 16 + 13 - 1', '-3 + 13 - 1', '10 - 1', '9'],
#  ['0 - 19 + 11 + 16', '-19 + 11 + 16', '-8 + 16', '8'],
#  ['10 * 1 * 17 + 4', '10 * 17 + 4', '170 + 4', '174'],
#  ['16 * 0 + 5 * 12', '0 + 5 * 12', '0 + 60', '60'],
#  ['12 * 8 - 12 * 0', '96 - 12 * 0', '96 - 0', '96'],
#  ['13 * 8 + 3 + 10', '104 + 3 + 10', '107 + 10', '117'],
#  ['18 - 5 - 12 + 8', '13 - 12 + 8', '1 + 8', '9'],
#  ['5 * 6 * 9 * 4', '30 * 9 * 4', '270 * 4', '1080'],
#  ['11 + 15 - 4 * 18', '11 + 15 - 72', '26 - 72', '-46'],
#  ['3 * 12 + 9 + 9', '36 + 9 + 9', '45 + 9', '54'],
#  ['5 + 6 * 13 * 10', '5 + 78 * 10', '5 + 780', '785'],
#  ['4 + 6 * 18 * 4', '4 + 108 * 4', '4 + 432', '436'],
#  ['5 + 11 + 12 * 18', '5 + 11 + 216', '16 + 216', '232'],
#  ['18 - 8 - 9 - 4', '10 - 9 - 4', '1 - 4', '-3'],
#  ['1 + 6 * 14 * 14', '1 + 84 * 14', '1 + 1176', '1177'],
#  ['12 - 16 - 16 - 16', '-4 - 16 - 16', '-20 - 16', '-36'],
#  ['1 + 2 + 12 - 8', '3 + 12 - 8', '15 - 8', '7'],
#  ['4 * 1 - 14 * 15', '4 - 14 * 15', '4 - 210', '-206'],
#  ['10 * 15 * 15 - 6', '150 * 15 - 6', '2250 - 6', '2244'],
#  ['17 - 13 * 3 * 14', '17 - 39 * 14', '17 - 546', '-529'],
#  ['0 * 12 - 10 - 9', '0 - 10 - 9', '-10 - 9', '-19'],
#  ['2 - 14 * 17 * 15', '2 - 238 * 15', '2 - 3570', '-3568'],
#  ['13 - 16 + 18 - 4', '-3 + 18 - 4', '15 - 4', '11'],
#  ['8 - 13 * 9 * 13', '8 - 117 * 13', '8 - 1521', '-1513'],
#  ['12 * 2 * 6 - 10', '24 * 6 - 10', '144 - 10', '134'],
#  ['13 + 16 - 6 + 12', '29 - 6 + 12', '23 + 12', '35'],
#  ['1 + 19 + 16 - 16', '20 + 16 - 16', '36 - 16', '20'],
#  ['16 + 2 + 10 - 3', '18 + 10 - 3', '28 - 3', '25'],
#  ['14 * 1 * 5 - 2', '14 * 5 - 2', '70 - 2', '68'],
#  ['18 - 15 * 14 * 16', '18 - 210 * 16', '18 - 3360', '-3342'],
#  ['1 - 6 + 17 + 2', '-5 + 17 + 2', '12 + 2', '14'],
#  ['6 + 2 - 2 - 13', '8 - 2 - 13', '6 - 13', '-7'],
#  ['8 - 11 - 4 - 6', '-3 - 4 - 6', '-7 - 6', '-13'],
#  ['15 - 0 + 11 - 11', '15 + 11 - 11', '26 - 11', '15'],
#  ['2 - 4 + 5 - 14', '-2 + 5 - 14', '3 - 14', '-11'],
#  ['3 - 5 + 15 - 4', '-2 + 15 - 4', '13 - 4', '9'],
#  ['17 - 10 * 0 + 8', '17 - 0 + 8', '17 + 8', '25'],
#  ['3 + 4 * 2 - 9', '3 + 8 - 9', '11 - 9', '2'],
#  ['14 * 13 * 13 * 7', '182 * 13 * 7', '2366 * 7', '16562'],
#  ['15 + 2 - 5 + 1', '17 - 5 + 1', '12 + 1', '13'],
#  ['15 + 16 + 1 * 3', '15 + 16 + 3', '31 + 3', '34'],
#  ['12 * 4 + 10 - 12', '48 + 10 - 12', '58 - 12', '46'],
#  ['2 - 0 + 12 * 3', '2 - 0 + 36', '2 + 36', '38'],
#  ['2 + 3 * 10 + 8', '2 + 30 + 8', '32 + 8', '40'],
#  ['0 + 11 + 8 - 6', '11 + 8 - 6', '19 - 6', '13'],
#  ['11 - 14 * 19 - 1', '11 - 266 - 1', '-255 - 1', '-256'],
#  ['8 - 8 * 12 + 19', '8 - 96 + 19', '-88 + 19', '-69'],
#  ['0 * 0 - 18 * 18', '0 - 18 * 18', '0 - 324', '-324'],
#  ['12 + 7 - 0 - 19', '19 - 0 - 19', '19 - 19', '0'],
#  ['9 * 5 * 5 * 6', '45 * 5 * 6', '225 * 6', '1350'],
#  ['0 - 5 * 14 + 19', '0 - 70 + 19', '-70 + 19', '-51'],
#  ['2 - 0 * 0 * 4', '2 - 0 * 4', '2 - 0', '2'],
#  ['12 + 2 * 2 * 7', '12 + 4 * 7', '12 + 28', '40'],
#  ['11 - 19 - 14 + 6', '-8 - 14 + 6', '-22 + 6', '-16'],
#  ['6 + 18 * 11 - 10', '6 + 198 - 10', '204 - 10', '194'],
#  ['10 * 7 * 14 * 9', '70 * 14 * 9', '980 * 9', '8820'],
#  ['9 - 6 * 12 - 6', '9 - 72 - 6', '-63 - 6', '-69'],
#  ['11 * 12 - 7 - 12', '132 - 7 - 12', '125 - 12', '113'],
#  ['0 * 19 * 15 + 16', '0 * 15 + 16', '0 + 16', '16'],
#  ['12 + 3 + 13 - 16', '15 + 13 - 16', '28 - 16', '12'],
#  ['18 + 9 - 4 + 6', '27 - 4 + 6', '23 + 6', '29'],
#  ['12 * 15 * 13 - 16', '180 * 13 - 16', '2340 - 16', '2324'],
#  ['19 + 18 * 0 - 3', '19 + 0 - 3', '19 - 3', '16'],
#  ['8 + 7 + 11 + 15', '15 + 11 + 15', '26 + 15', '41'],
#  ['5 * 10 + 18 + 7', '50 + 18 + 7', '68 + 7', '75'],
#  ['1 - 6 + 11 - 8', '-5 + 11 - 8', '6 - 8', '-2'],
#  ['15 * 10 - 2 - 7', '150 - 2 - 7', '148 - 7', '141'],
#  ['18 * 10 - 11 + 18', '180 - 11 + 18', '169 + 18', '187'],
#  ['18 * 4 - 0 - 10', '72 - 0 - 10', '72 - 10', '62'],
#  ['19 * 15 * 12 - 10', '285 * 12 - 10', '3420 - 10', '3410'],
#  ['15 * 18 - 19 - 18', '270 - 19 - 18', '251 - 18', '233'],
#  ['1 + 13 + 8 * 6', '1 + 13 + 48', '14 + 48', '62'],
#  ['14 * 12 + 14 + 14', '168 + 14 + 14', '182 + 14', '196'],
#  ['1 * 14 - 13 - 14', '14 - 13 - 14', '1 - 14', '-13'],
#  ['14 + 11 - 11 * 5', '14 + 11 - 55', '25 - 55', '-30'],
#  ['18 + 12 + 13 * 9', '18 + 12 + 117', '30 + 117', '147'],
#  ['13 + 18 - 3 * 14', '13 + 18 - 42', '31 - 42', '-11'],
#  ['0 * 10 * 2 - 8', '0 * 2 - 8', '0 - 8', '-8'],
#  ['15 + 1 - 16 - 9', '16 - 16 - 9', '0 - 9', '-9'],
#  ['10 * 18 - 14 * 4', '180 - 14 * 4', '180 - 56', '124'],
#  ['19 * 1 - 9 + 6', '19 - 9 + 6', '10 + 6', '16'],
#  ['16 * 19 + 1 + 15', '304 + 1 + 15', '305 + 15', '320'],
#  ['15 - 2 - 7 + 15', '13 - 7 + 15', '6 + 15', '21'],
#  ['9 * 7 + 4 - 18', '63 + 4 - 18', '67 - 18', '49'],
#  ['2 * 0 - 4 + 1', '0 - 4 + 1', '-4 + 1', '-3'],
#  ['16 * 8 + 7 - 16', '128 + 7 - 16', '135 - 16', '119'],
#  ['15 - 0 * 5 - 5', '15 - 0 - 5', '15 - 5', '10'],
#  ['0 * 4 * 15 - 15', '0 * 15 - 15', '0 - 15', '-15'],
#  ['3 * 17 * 18 - 1', '51 * 18 - 1', '918 - 1', '917'],
#  ['0 + 8 + 3 * 3', '0 + 8 + 9', '8 + 9', '17'],
#  ['9 - 10 + 5 * 19', '9 - 10 + 95', '-1 + 95', '94'],
#  ['15 - 5 * 11 - 6', '15 - 55 - 6', '-40 - 6', '-46'],
#  ['19 * 7 * 9 - 12', '133 * 9 - 12', '1197 - 12', '1185'],
#  ['5 + 1 * 8 + 8', '5 + 8 + 8', '13 + 8', '21'],
#  ['16 * 9 * 7 - 12', '144 * 7 - 12', '1008 - 12', '996'],
#  ['8 - 7 + 4 + 10', '1 + 4 + 10', '5 + 10', '15'],
#  ['6 * 2 * 8 + 12', '12 * 8 + 12', '96 + 12', '108'],
#  ['2 * 2 * 6 * 5', '4 * 6 * 5', '24 * 5', '120'],
#  ['17 * 4 + 6 * 19', '68 + 6 * 19', '68 + 114', '182'],
#  ['3 + 0 * 11 - 16', '3 + 0 - 16', '3 - 16', '-13'],
#  ['2 - 10 * 6 - 17', '2 - 60 - 17', '-58 - 17', '-75'],
#  ['10 * 3 + 6 - 2', '30 + 6 - 2', '36 - 2', '34'],
#  ['2 - 3 + 10 + 15', '-1 + 10 + 15', '9 + 15', '24'],
#  ['3 - 14 - 3 + 9', '-11 - 3 + 9', '-14 + 9', '-5'],
#  ['11 + 14 - 12 + 3', '25 - 12 + 3', '13 + 3', '16'],
#  ['15 * 19 * 2 + 11', '285 * 2 + 11', '570 + 11', '581'],
#  ['2 + 15 - 3 + 9', '17 - 3 + 9', '14 + 9', '23'],
#  ['9 + 1 * 3 * 3', '9 + 3 * 3', '9 + 9', '18'],
#  ['16 - 11 - 11 * 9', '16 - 11 - 99', '5 - 99', '-94'],
#  ['6 - 7 - 17 - 13', '-1 - 17 - 13', '-18 - 13', '-31'],
#  ['2 * 8 * 4 * 18', '16 * 4 * 18', '64 * 18', '1152'],
#  ['12 * 12 - 10 - 5', '144 - 10 - 5', '134 - 5', '129'],
#  ['11 - 3 * 13 + 16', '11 - 39 + 16', '-28 + 16', '-12'],
#  ['15 + 13 + 16 + 9', '28 + 16 + 9', '44 + 9', '53'],
#  ['16 * 7 * 19 - 11', '112 * 19 - 11', '2128 - 11', '2117'],
#  ['0 * 2 - 7 * 7', '0 - 7 * 7', '0 - 49', '-49'],
#  ['15 - 17 + 2 - 6', '-2 + 2 - 6', '0 - 6', '-6'],
#  ['11 + 11 + 14 + 9', '22 + 14 + 9', '36 + 9', '45'],
#  ['0 + 10 * 11 - 14', '0 + 110 - 14', '110 - 14', '96'],
#  ['11 * 8 - 5 - 2', '88 - 5 - 2', '83 - 2', '81'],
#  ['15 * 3 * 6 + 14', '45 * 6 + 14', '270 + 14', '284'],
#  ['5 + 17 - 1 + 14', '22 - 1 + 14', '21 + 14', '35'],
#  ['17 - 18 + 4 + 0', '-1 + 4 + 0', '3 + 0', '3'],
#  ['10 * 12 - 14 - 1', '120 - 14 - 1', '106 - 1', '105'],
#  ['18 + 3 + 1 * 17', '18 + 3 + 17', '21 + 17', '38'],
#  ['1 * 7 - 4 + 14', '7 - 4 + 14', '3 + 14', '17'],
#  ['18 * 11 + 18 * 9', '198 + 18 * 9', '198 + 162', '360'],
#  ['3 + 1 + 2 - 9', '4 + 2 - 9', '6 - 9', '-3'],
#  ['8 * 10 - 18 - 14', '80 - 18 - 14', '62 - 14', '48'],
#  ['18 * 0 + 7 + 19', '0 + 7 + 19', '7 + 19', '26'],
#  ['8 - 14 + 2 - 6', '-6 + 2 - 6', '-4 - 6', '-10'],
#  ['12 - 11 + 6 * 4', '12 - 11 + 24', '1 + 24', '25'],
#  ['16 + 11 - 9 + 16', '27 - 9 + 16', '18 + 16', '34'],
#  ['4 * 13 * 9 * 12', '52 * 9 * 12', '468 * 12', '5616'],
#  ['5 - 5 + 2 + 17', '0 + 2 + 17', '2 + 17', '19'],
#  ['8 + 13 + 1 * 15', '8 + 13 + 15', '21 + 15', '36'],
#  ['1 - 14 - 1 - 8', '-13 - 1 - 8', '-14 - 8', '-22'],
#  ['18 - 0 - 16 * 11', '18 - 0 - 176', '18 - 176', '-158'],
#  ['7 - 1 - 0 * 2', '7 - 1 - 0', '6 - 0', '6'],
#  ['16 + 3 - 5 - 3', '19 - 5 - 3', '14 - 3', '11'],
#  ['17 - 2 + 11 * 6', '17 - 2 + 66', '15 + 66', '81'],
#  ['12 + 3 + 5 + 18', '15 + 5 + 18', '20 + 18', '38'],
#  ['2 - 5 * 6 * 15', '2 - 30 * 15', '2 - 450', '-448'],
#  ['18 * 13 * 16 * 0', '234 * 16 * 0', '3744 * 0', '0'],
#  ['13 - 8 - 12 * 9', '13 - 8 - 108', '5 - 108', '-103'],
#  ['15 * 4 * 3 * 12', '60 * 3 * 12', '180 * 12', '2160'],
#  ['17 * 15 - 8 * 14', '255 - 8 * 14', '255 - 112', '143'],
#  ['10 + 17 * 19 - 16', '10 + 323 - 16', '333 - 16', '317'],
#  ['12 + 18 + 2 + 4', '30 + 2 + 4', '32 + 4', '36'],
#  ['11 - 0 - 7 - 8', '11 - 7 - 8', '4 - 8', '-4'],
#  ['9 - 0 * 15 + 10', '9 - 0 + 10', '9 + 10', '19'],
#  ['6 + 2 * 7 * 2', '6 + 14 * 2', '6 + 28', '34'],
#  ['9 + 7 + 15 + 19', '16 + 15 + 19', '31 + 19', '50'],
#  ['11 - 19 - 16 * 7', '11 - 19 - 112', '-8 - 112', '-120'],
#  ['14 * 6 * 2 + 18', '84 * 2 + 18', '168 + 18', '186'],
#  ['9 * 8 + 7 * 1', '72 + 7 * 1', '72 + 7', '79'],
#  ['18 * 0 - 3 * 12', '0 - 3 * 12', '0 - 36', '-36'],
#  ['18 * 11 * 16 * 18', '198 * 16 * 18', '3168 * 18', '57024'],
#  ['3 + 13 + 8 - 1', '16 + 8 - 1', '24 - 1', '23'],
#  ['5 * 15 + 5 * 17', '75 + 5 * 17', '75 + 85', '160'],
#  ['18 - 2 + 7 * 3', '18 - 2 + 21', '16 + 21', '37'],
#  ['17 * 0 + 4 - 18', '0 + 4 - 18', '4 - 18', '-14'],
#  ['6 - 14 - 9 + 17', '-8 - 9 + 17', '-17 + 17', '0'],
#  ['8 + 1 * 5 - 7', '8 + 5 - 7', '13 - 7', '6'],
#  ['0 - 7 + 6 + 1', '-7 + 6 + 1', '-1 + 1', '0'],
#  ['8 + 5 + 9 - 19', '13 + 9 - 19', '22 - 19', '3'],
#  ['2 * 6 - 8 * 18', '12 - 8 * 18', '12 - 144', '-132'],
#  ['0 - 2 - 2 * 1', '0 - 2 - 2', '-2 - 2', '-4'],
#  ['1 + 5 * 8 * 4', '1 + 40 * 4', '1 + 160', '161'],
#  ['11 + 5 - 2 + 2', '16 - 2 + 2', '14 + 2', '16'],
#  ['0 - 12 - 18 * 15', '0 - 12 - 270', '-12 - 270', '-282'],
#  ['9 - 5 * 0 * 14', '9 - 0 * 14', '9 - 0', '9'],
#  ['16 + 5 + 14 + 15', '21 + 14 + 15', '35 + 15', '50'],
#  ['11 + 11 - 13 + 11', '22 - 13 + 11', '9 + 11', '20'],
#  ['16 - 15 - 13 - 8', '1 - 13 - 8', '-12 - 8', '-20'],
#  ['5 * 5 + 11 + 17', '25 + 11 + 17', '36 + 17', '53'],
#  ['7 * 1 + 2 * 4', '7 + 2 * 4', '7 + 8', '15'],
#  ['0 - 10 * 14 * 8', '0 - 140 * 8', '0 - 1120', '-1120'],
#  ['4 + 3 + 4 - 2', '7 + 4 - 2', '11 - 2', '9'],
#  ['16 + 7 - 18 + 7', '23 - 18 + 7', '5 + 7', '12'],
#  ['11 * 10 * 2 + 3', '110 * 2 + 3', '220 + 3', '223'],
#  ['2 * 1 + 7 - 7', '2 + 7 - 7', '9 - 7', '2'],
#  ['11 * 9 * 6 * 5', '99 * 6 * 5', '594 * 5', '2970'],
#  ['3 - 18 - 13 - 4', '-15 - 13 - 4', '-28 - 4', '-32'],
#  ['4 - 0 + 16 - 0', '4 + 16 - 0', '20 - 0', '20'],
#  ['0 + 7 + 7 + 18', '7 + 7 + 18', '14 + 18', '32'],
#  ['14 * 0 + 12 - 2', '0 + 12 - 2', '12 - 2', '10'],
#  ['3 * 9 - 4 * 12', '27 - 4 * 12', '27 - 48', '-21'],
#  ['16 + 17 - 16 - 6', '33 - 16 - 6', '17 - 6', '11'],
#  ['6 + 10 - 12 * 0', '6 + 10 - 0', '16 - 0', '16'],
#  ['13 - 11 * 19 * 1', '13 - 209 * 1', '13 - 209', '-196'],
#  ['6 - 8 - 8 * 11', '6 - 8 - 88', '-2 - 88', '-90'],
#  ['12 * 0 * 5 - 14', '0 * 5 - 14', '0 - 14', '-14'],
#  ['3 + 1 * 14 - 5', '3 + 14 - 5', '17 - 5', '12'],
#  ['4 + 16 + 14 * 13', '4 + 16 + 182', '20 + 182', '202'],
#  ['9 + 4 * 17 * 9', '9 + 68 * 9', '9 + 612', '621'],
#  ['19 * 16 - 14 - 11', '304 - 14 - 11', '290 - 11', '279'],
#  ['6 * 13 + 6 * 4', '78 + 6 * 4', '78 + 24', '102'],
#  ['1 + 5 - 7 * 4', '1 + 5 - 28', '6 - 28', '-22'],
#  ['16 - 19 + 19 - 2', '-3 + 19 - 2', '16 - 2', '14'],
#  ['6 - 2 - 5 - 4', '4 - 5 - 4', '-1 - 4', '-5'],
#  ['1 * 3 - 7 + 14', '3 - 7 + 14', '-4 + 14', '10'],
#  ['6 - 17 + 13 + 12', '-11 + 13 + 12', '2 + 12', '14'],
#  ['7 * 4 - 16 * 3', '28 - 16 * 3', '28 - 48', '-20'],
#  ['16 + 15 + 9 * 7', '16 + 15 + 63', '31 + 63', '94'],
#  ['2 + 6 * 16 + 13', '2 + 96 + 13', '98 + 13', '111'],
#  ['4 * 10 * 16 - 12', '40 * 16 - 12', '640 - 12', '628'],
#  ['14 * 7 - 12 * 5', '98 - 12 * 5', '98 - 60', '38'],
#  ['9 - 13 * 7 * 15', '9 - 91 * 15', '9 - 1365', '-1356'],
#  ['4 - 11 + 17 - 10', '-7 + 17 - 10', '10 - 10', '0'],
#  ['4 + 12 * 8 + 16', '4 + 96 + 16', '100 + 16', '116'],
#  ['16 + 0 - 16 + 8', '16 - 16 + 8', '0 + 8', '8'],
#  ['2 + 5 - 8 * 14', '2 + 5 - 112', '7 - 112', '-105'],
#  ['14 * 14 - 3 * 3', '196 - 3 * 3', '196 - 9', '187'],
#  ['6 - 9 - 16 - 13', '-3 - 16 - 13', '-19 - 13', '-32'],
#  ['19 - 12 - 3 * 9', '19 - 12 - 27', '7 - 27', '-20'],
#  ['5 - 1 * 7 + 13', '5 - 7 + 13', '-2 + 13', '11'],
#  ['7 * 8 + 11 - 3', '56 + 11 - 3', '67 - 3', '64'],
#  ['10 * 19 * 0 * 19', '190 * 0 * 19', '0 * 19', '0'],
#  ['0 - 7 * 11 * 19', '0 - 77 * 19', '0 - 1463', '-1463'],
#  ['1 * 0 + 6 + 9', '0 + 6 + 9', '6 + 9', '15'],
#  ['19 + 13 + 0 - 11', '32 + 0 - 11', '32 - 11', '21'],
#  ['12 + 10 + 17 - 10', '22 + 17 - 10', '39 - 10', '29'],
#  ['13 * 7 * 15 - 17', '91 * 15 - 17', '1365 - 17', '1348'],
#  ['2 + 19 + 0 - 1', '21 + 0 - 1', '21 - 1', '20'],
#  ['19 + 15 - 3 - 8', '34 - 3 - 8', '31 - 8', '23'],
#  ['10 - 9 + 9 * 6', '10 - 9 + 54', '1 + 54', '55'],
#  ['15 + 5 + 14 + 5', '20 + 14 + 5', '34 + 5', '39'],
#  ['2 * 0 - 13 * 9', '0 - 13 * 9', '0 - 117', '-117'],
#  ['3 + 1 - 17 * 7', '3 + 1 - 119', '4 - 119', '-115'],
#  ['19 * 1 * 19 * 3', '19 * 19 * 3', '361 * 3', '1083'],
#  ['6 * 18 + 3 + 8', '108 + 3 + 8', '111 + 8', '119'],
#  ['8 + 14 - 8 - 0', '22 - 8 - 0', '14 - 0', '14'],
#  ['1 * 16 - 19 + 17', '16 - 19 + 17', '-3 + 17', '14'],
#  ['13 - 10 - 16 - 11', '3 - 16 - 11', '-13 - 11', '-24'],
#  ['2 * 5 - 3 - 18', '10 - 3 - 18', '7 - 18', '-11'],
#  ['0 + 17 - 2 + 10', '17 - 2 + 10', '15 + 10', '25'],
#  ['1 + 2 - 8 + 13', '3 - 8 + 13', '-5 + 13', '8'],
#  ['9 + 14 + 15 * 12', '9 + 14 + 180', '23 + 180', '203'],
#  ['14 - 13 * 2 + 0', '14 - 26 + 0', '-12 + 0', '-12'],
#  ['16 + 12 + 7 + 6', '28 + 7 + 6', '35 + 6', '41'],
#  ['10 * 15 + 15 + 14', '150 + 15 + 14', '165 + 14', '179'],
#  ['10 * 4 + 12 + 0', '40 + 12 + 0', '52 + 0', '52'],
#  ['5 + 0 * 8 + 13', '5 + 0 + 13', '5 + 13', '18'],
#  ['6 * 15 + 16 - 6', '90 + 16 - 6', '106 - 6', '100'],
#  ['0 - 8 + 5 + 10', '-8 + 5 + 10', '-3 + 10', '7'],
#  ['2 - 0 - 10 * 9', '2 - 0 - 90', '2 - 90', '-88'],
#  ['0 - 4 * 17 * 13', '0 - 68 * 13', '0 - 884', '-884'],
#  ['6 * 13 + 8 * 3', '78 + 8 * 3', '78 + 24', '102'],
#  ['19 - 7 - 14 - 2', '12 - 14 - 2', '-2 - 2', '-4'],
#  ['6 + 9 - 2 - 19', '15 - 2 - 19', '13 - 19', '-6'],
#  ['17 * 8 * 4 * 11', '136 * 4 * 11', '544 * 11', '5984'],
#  ['2 - 14 - 7 * 6', '2 - 14 - 42', '-12 - 42', '-54'],
#  ['1 - 16 - 14 - 16', '-15 - 14 - 16', '-29 - 16', '-45'],
#  ['5 + 7 + 16 * 2', '5 + 7 + 32', '12 + 32', '44'],
#  ['7 * 9 + 10 - 8', '63 + 10 - 8', '73 - 8', '65'],
#  ['9 + 14 * 6 - 8', '9 + 84 - 8', '93 - 8', '85'],
#  ['2 - 11 + 11 + 11', '-9 + 11 + 11', '2 + 11', '13'],
#  ['19 - 19 - 1 - 11', '0 - 1 - 11', '-1 - 11', '-12'],
#  ['2 - 15 + 1 + 14', '-13 + 1 + 14', '-12 + 14', '2'],
#  ['7 - 1 * 3 + 17', '7 - 3 + 17', '4 + 17', '21'],
#  ['12 * 5 - 11 * 7', '60 - 11 * 7', '60 - 77', '-17'],
#  ['5 * 4 * 17 - 7', '20 * 17 - 7', '340 - 7', '333'],
#  ['14 + 19 - 3 + 9', '33 - 3 + 9', '30 + 9', '39'],
#  ['15 - 10 - 6 - 16', '5 - 6 - 16', '-1 - 16', '-17'],
#  ['5 + 9 * 1 * 16', '5 + 9 * 16', '5 + 144', '149'],
#  ['3 + 13 - 13 + 13', '16 - 13 + 13', '3 + 13', '16'],
#  ['13 + 5 - 19 - 6', '18 - 19 - 6', '-1 - 6', '-7'],
#  ['19 - 2 + 17 + 2', '17 + 17 + 2', '34 + 2', '36'],
#  ['0 * 13 * 12 + 7', '0 * 12 + 7', '0 + 7', '7'],
#  ['2 + 15 - 6 - 17', '17 - 6 - 17', '11 - 17', '-6'],
#  ['3 * 12 + 16 + 4', '36 + 16 + 4', '52 + 4', '56'],
#  ['12 + 18 * 7 + 3', '12 + 126 + 3', '138 + 3', '141'],
#  ['8 * 5 - 6 * 14', '40 - 6 * 14', '40 - 84', '-44'],
#  ['6 * 11 + 4 - 7', '66 + 4 - 7', '70 - 7', '63'],
#  ['19 * 19 - 11 - 9', '361 - 11 - 9', '350 - 9', '341'],
#  ['7 - 19 - 10 - 17', '-12 - 10 - 17', '-22 - 17', '-39'],
#  ['6 + 12 + 8 * 8', '6 + 12 + 64', '18 + 64', '82'],
#  ['10 + 14 * 10 - 2', '10 + 140 - 2', '150 - 2', '148'],
#  ['14 * 7 - 3 * 13', '98 - 3 * 13', '98 - 39', '59'],
#  ['13 * 18 + 1 - 19', '234 + 1 - 19', '235 - 19', '216'],
#  ['0 * 9 + 19 - 19', '0 + 19 - 19', '19 - 19', '0'],
#  ['0 + 5 * 14 * 10', '0 + 70 * 10', '0 + 700', '700'],
#  ['6 + 8 * 9 + 4', '6 + 72 + 4', '78 + 4', '82'],
#  ['14 + 19 - 18 - 19', '33 - 18 - 19', '15 - 19', '-4'],
#  ['16 - 5 - 11 - 7', '11 - 11 - 7', '0 - 7', '-7'],
#  ['7 + 12 + 17 - 2', '19 + 17 - 2', '36 - 2', '34'],
#  ['11 - 8 * 5 - 19', '11 - 40 - 19', '-29 - 19', '-48'],
#  ['2 * 8 + 15 * 6', '16 + 15 * 6', '16 + 90', '106'],
#  ['10 - 1 * 4 - 3', '10 - 4 - 3', '6 - 3', '3'],
#  ['5 + 18 * 13 + 5', '5 + 234 + 5', '239 + 5', '244'],
#  ['15 * 13 + 1 + 10', '195 + 1 + 10', '196 + 10', '206'],
#  ['12 * 13 * 7 * 11', '156 * 7 * 11', '1092 * 11', '12012'],
#  ['16 * 16 * 0 + 4', '256 * 0 + 4', '0 + 4', '4'],
#  ['1 + 13 + 2 - 8', '14 + 2 - 8', '16 - 8', '8'],
#  ['16 + 1 * 6 * 8', '16 + 6 * 8', '16 + 48', '64'],
#  ['16 - 10 * 12 + 15', '16 - 120 + 15', '-104 + 15', '-89'],
#  ['17 - 17 + 8 + 13', '0 + 8 + 13', '8 + 13', '21'],
#  ['7 + 8 * 5 * 15', '7 + 40 * 15', '7 + 600', '607'],
#  ['7 - 19 - 14 * 18', '7 - 19 - 252', '-12 - 252', '-264'],
#  ['5 + 16 + 7 - 7', '21 + 7 - 7', '28 - 7', '21'],
#  ['18 * 7 - 10 * 6', '126 - 10 * 6', '126 - 60', '66'],
#  ['17 + 15 + 1 + 3', '32 + 1 + 3', '33 + 3', '36'],
#  ['10 + 0 - 19 - 5', '10 - 19 - 5', '-9 - 5', '-14'],
#  ['7 + 9 * 11 + 16', '7 + 99 + 16', '106 + 16', '122'],
#  ['13 + 12 - 2 * 7', '13 + 12 - 14', '25 - 14', '11'],
#  ['16 + 8 * 9 + 14', '16 + 72 + 14', '88 + 14', '102'],
#  ['9 - 14 - 9 * 5', '9 - 14 - 45', '-5 - 45', '-50'],
#  ...]

# %%
# np.save('../arithmetic/7step_train.npy', dataset)
np.save('../arithmetic/7step_eval.npy', dataset)
